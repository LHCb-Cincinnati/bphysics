# %%
import os
import subprocess
import uproot
import numpy as np
from multiprocessing import Pool
from tqdm import tqdm

# %% [markdown]
# # Extraction and Reduction

# %%
def is_file_corrupt(file_path):
    try:
        with uproot.open(file_path) as file:
            file.keys()
        return False
    except:
        return True

# %%
def process_file(args):
    filename, input_folder, output_folder, decay_tree_line, branches_to_keep = args
    input_file_path = os.path.join(input_folder, filename)
    output_file_path = os.path.join(output_folder, filename.replace('.root', '_reduced.root'))

    if os.path.exists(output_file_path):
        return f"Skipped existing file: {output_file_path}"
    if is_file_corrupt(input_file_path):
        return f"File {filename} seems to be corrupt. Skipping."

    try:
        with uproot.open(input_file_path) as file:
            if decay_tree_line not in file:
                return f"Tree {decay_tree_line} not found in {filename}. Skipping."

            tree = file[decay_tree_line]
            data = tree.arrays(expressions=branches_to_keep, library="np")
            
            # Number of events before pre-selection
            num_events_before = len(data['Bu_MM'])
            
            # Calculations for pre-selection
            Delta_Z = data['L0_ENDVERTEX_Z'] - data['Bu_ENDVERTEX_Z']
            Delta_X = data['L0_ENDVERTEX_X'] - data['Bu_ENDVERTEX_X']
            Delta_Y = data['L0_ENDVERTEX_Y'] - data['Bu_ENDVERTEX_Y']

            Delta_X_ERR = np.sqrt(np.square(data['Bu_ENDVERTEX_XERR']) + np.square(data['L0_ENDVERTEX_XERR']))
            Delta_Y_ERR = np.sqrt(np.square(data['Bu_ENDVERTEX_YERR']) + np.square(data['L0_ENDVERTEX_YERR']))
            Delta_Z_ERR = np.sqrt(np.square(data['Bu_ENDVERTEX_ZERR']) + np.square(data['L0_ENDVERTEX_ZERR']))

            delta_x = np.divide(Delta_X, Delta_X_ERR, out=np.zeros_like(Delta_X), where=Delta_X_ERR!=0)
            delta_y = np.divide(Delta_Y, Delta_Y_ERR, out=np.zeros_like(Delta_Y), where=Delta_Y_ERR!=0)
            delta_z = np.divide(Delta_Z, Delta_Z_ERR, out=np.zeros_like(Delta_Z), where=Delta_Z_ERR!=0)

            L0_FD_CHISQ = np.square(delta_x) + np.square(delta_y) + np.square(delta_z)

            prodProbKK = np.multiply(data['h1_ProbNNk'], data['h2_ProbNNk'])

            # Apply pre-selection
            pre_select = (data['Bu_FDCHI2_OWNPV'] > 175) & (Delta_Z > 2.5) & \
                         (data['Lp_ProbNNp'] > 0.05) & (data['p_ProbNNp'] > 0.05) & \
                         (prodProbKK > 0.10) & (data['Bu_DTF_chi2'] < 30) & (data['Bu_PT'] > 3000)
            data = {branch: values[pre_select] for branch, values in data.items()}

            # Number of events after pre-selection
            num_events_after = len(data['Bu_MM'])
            
            # Percentage of events remaining
            percent_remaining = (num_events_after / num_events_before) * 100 if num_events_before > 0 else 0

            with uproot.recreate(output_file_path) as new_file:
                new_file[decay_tree_line] = data

            return f"Processed {filename}: {num_events_before} events before, {num_events_after} after ({percent_remaining:.2f}% remaining)"
    except Exception as e:
        return f"Error processing {filename}: {e}"

# %%
def main(year, magnet, decay_tree, ll_or_dd, num_files=None):
    
    # Extract the base name from the decay tree (e.g., "B2L0barPKpKm" from "B2L0barPKpKm_LL")
    decay_tree_base = decay_tree.split('_')[0]

    # Check for consistency between decay_tree and ll_or_dd arguments
    if ('_LL/' in decay_tree and ll_or_dd != 'LL') or ('_DD/' in decay_tree and ll_or_dd != 'DD'):
        raise ValueError("Inconsistency in decay_tree and ll_or_dd. Both should be LL or DD.")
        
    input_folder = f"/eos/lhcb/wg/BnoC/Bu2LambdaPPP/RD/restripped.data/reduced/{year}{magnet}/"
    output_folder = f"/eos/lhcb/user/m/melashri/data/red_RD/{decay_tree_base}/{year}/{magnet}/{ll_or_dd}"

    # Print the output folder location
    print(f"Output files will be saved in: {output_folder}")
    
    # Check if the output folder exists, otherwise create it
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    # The list of branches to keep
    branches_to_keep = ['Bu_MM', 'Bu_MMERR', 'Bu_ID', 'Bu_P', 'Bu_PT', 'Bu_PE', 'Bu_PX', 'Bu_PY', 'Bu_PZ', 
                    'h1_P', 'h1_PT','h1_PE', 'h1_PX', 'h1_PY', 'h1_PZ', 
                    'h1_ID', 'h1_TRACK_Type', 'h1_IPCHI2_OWNPV', 'h1_PIDK', 'h1_PIDp',
                    'h2_P', 'h2_PT', 'h2_PE', 'h2_PX','h2_PY', 'h2_PZ', 
                    'h2_ID', 'h2_TRACK_Type', 'h2_IPCHI2_OWNPV', 'h2_PIDK', 'h2_PIDp',
                    'p_P', 'p_PT', 'p_PE', 'p_PX', 'p_PY', 'p_PZ', 
                    'p_ID', 'p_TRACK_Type', 'p_IPCHI2_OWNPV', 'p_PIDK', 'p_PIDp',
                    'Lp_P', 'Lp_PT', 'Lp_PE', 'Lp_PX', 'Lp_PY', 'Lp_PZ', 'Lp_ID', 'Lp_TRACK_Type', 'Lp_PIDK', 'Lp_PIDp', 
                    'L0_P',
                    'L0_PT', 'L0_PE', 'L0_PX', 'L0_PY', 'L0_PZ', 'L0_ID', 'Lpi_P', 'Lpi_PT', 'Lpi_PE', 'Lpi_PX', 'Lpi_PY', 
                    'Lpi_PZ', 'Lpi_ID', 'Lpi_TRACK_Type', 'p_ProbNNp', 'Lpi_ProbNNpi', 'Lp_ProbNNp', 'h1_ProbNNk', 'h2_ProbNNk',
                    'Bu_FDCHI2_OWNPV', 'Bu_IPCHI2_OWNPV', 'Bu_ENDVERTEX_X', 'Bu_ENDVERTEX_Y', 'Bu_ENDVERTEX_Z', 'Bu_ENDVERTEX_XERR', 
                    'Bu_ENDVERTEX_YERR', 'Bu_ENDVERTEX_ZERR', 'Bu_DTF_decayLength', 'Bu_DTF_decayLengthErr', 'Bu_DTF_ctau', 
                    'Bu_DTF_ctauErr', 'Bu_DTF_status', 'Bu_DTFL0_M', 'Bu_DTFL0_MERR', 'Bu_DTFL0_ctau', 'Bu_DTFL0_ctauErr', 'Bu_DTF_nPV',
                    'Bu_DTF_chi2', 'Bu_DTF_nDOF', 'L0_ENDVERTEX_X', 'L0_ENDVERTEX_Y', 'L0_ENDVERTEX_Z', 'L0_ENDVERTEX_XERR', 
                    'L0_ENDVERTEX_YERR', 'L0_ENDVERTEX_ZERR', 'L0_MM', 'L0_OWNPV_Z', 'L0_OWNPV_ZERR', 'L0_FD_OWNPV', 'L0_FDCHI2_OWNPV',
                    'Bu_L0Global_TIS', 'Bu_L0HadronDecision_TOS', 'Bu_Hlt1Global_TIS', 'Bu_Hlt1TrackMVADecision_TOS',
                    'Bu_Hlt1TwoTrackMVADecision_TOS', 'Bu_Hlt2Topo2BodyDecision_TOS', 'Bu_Hlt2Topo3BodyDecision_TOS', 'Bu_Hlt2Topo4BodyDecision_TOS',
                    'Bu_Hlt2Topo2BodyBBDTDecision_TOS', 'Bu_Hlt2Topo3BodyBBDTDecision_TOS', 'Bu_Hlt2Topo4BodyBBDTDecision_TOS',
                    'h1_PIDK', 'h1_PIDp', 'h2_PIDK', 'h2_PIDp', 'p_PIDK', 'p_PIDp',
                    'Bu_DTFL0_chi2', 'Bu_DTFL0_nDOF', 'Bu_DTFL0_status',
                    'nCandidate','totCandidates', 'EventInSequence', 'runNumber', 'eventNumber','GpsTime',
                    'Polarity', 
                    'Bu_DTFL0_Lambda0_M', 'Bu_DTFL0_Lambda0_ctau', 'Bu_DTFL0_Lambda0_ctauErr',
                    'Bu_DTFL0_Lambda0_decayLength', 'Bu_DTFL0_Lambda0_decayLengthErr',
                    'Lp_ProbNNghost', 'Lpi_ProbNNghost', 'p_ProbNNghost', 'h1_ProbNNghost', 'h2_ProbNNghost',
                       ]
    # Go through all files the ends with .root 
    root_files = [f for f in os.listdir(input_folder) if f.endswith('.root')]
    
    # Go through only the first couple files that passed by num_files
    if num_files is not None:
        root_files = root_files[:num_files]
    
    # Arguments for the main function
    args = [(filename, input_folder, output_folder, decay_tree, branches_to_keep) for filename in root_files]

    # Use multiprocessing with 4 cores (max on SWAN)
    with Pool(4) as p:
        results = list(tqdm(p.imap(process_file, args), total=len(root_files), desc="Processing files"))

        for result in results:
            print(result)

# %% [markdown]
# ## Run the Preprocessing

# %%
if __name__ == "__main__":
    year = "2017"
    magnet = "MagDown"
    decay_tree = "B2L0barPKpKm_LL/DecayTree"
    ll_or_dd = "LL"
    num_files = 16  # Process only the first 16 files for testing
    #main(year, magnet, decay_tree, ll_or_dd, num_files)
    main(year, magnet, decay_tree, ll_or_dd) # process all files
# Out:
# Output files will be saved in: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL
# Processing files: 100%|██████████| 1434/1434 [11:42<00:00,  2.04it/s]
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_0_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_10_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_100_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1000_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1001_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1002_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1003_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1004_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1005_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1006_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1007_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1008_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1009_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_101_reduced.root
# Skipped existing file: /eos/lhcb/user/m/melashri/data/reduced/2017/MagDown/LL/datadata_2017MagDown_1010_reduced.root
# Processed datadata_2017MagDown_1011.root: 353 events before, 204 after (57.79% remaining)
# Processed datadata_2017MagDown_1012.root: 251 events before, 139 after (55.38% remaining)
# Processed datadata_2017MagDown_1013.root: 351 events before, 203 after (57.83% remaining)
# Processed datadata_2017MagDown_1014.root: 371 events before, 224 after (60.38% remaining)
# Processed datadata_2017MagDown_1015.root: 334 events before, 197 after (58.98% remaining)
# Processed datadata_2017MagDown_1016.root: 360 events before, 204 after (56.67% remaining)
# Processed datadata_2017MagDown_1017.root: 269 events before, 167 after (62.08% remaining)
# Processed datadata_2017MagDown_1018.root: 379 events before, 209 after (55.15% remaining)
# Processed datadata_2017MagDown_1019.root: 318 events before, 188 after (59.12% remaining)
# Processed datadata_2017MagDown_102.root: 300 events before, 185 after (61.67% remaining)
# Processed datadata_2017MagDown_1020.root: 264 events before, 159 after (60.23% remaining)
# Processed datadata_2017MagDown_1021.root: 359 events before, 204 after (56.82% remaining)
# Processed datadata_2017MagDown_1022.root: 378 events before, 236 after (62.43% remaining)
# Processed datadata_2017MagDown_1023.root: 355 events before, 218 after (61.41% remaining)
# Processed datadata_2017MagDown_1024.root: 375 events before, 237 after (63.20% remaining)
# Processed datadata_2017MagDown_1025.root: 380 events before, 228 after (60.00% remaining)
# Processed datadata_2017MagDown_1026.root: 343 events before, 195 after (56.85% remaining)
# Processed datadata_2017MagDown_1027.root: 350 events before, 211 after (60.29% remaining)
# Processed datadata_2017MagDown_1028.root: 355 events before, 223 after (62.82% remaining)
# Processed datadata_2017MagDown_1029.root: 422 events before, 269 after (63.74% remaining)
# Processed datadata_2017MagDown_103.root: 305 events before, 158 after (51.80% remaining)
# Processed datadata_2017MagDown_1030.root: 373 events before, 239 after (64.08% remaining)
# Processed datadata_2017MagDown_1031.root: 348 events before, 216 after (62.07% remaining)
# Processed datadata_2017MagDown_1032.root: 370 events before, 226 after (61.08% remaining)
# Processed datadata_2017MagDown_1033.root: 378 events before, 239 after (63.23% remaining)
# Processed datadata_2017MagDown_1034.root: 360 events before, 228 after (63.33% remaining)
# Processed datadata_2017MagDown_1035.root: 323 events before, 204 after (63.16% remaining)
# Processed datadata_2017MagDown_1036.root: 269 events before, 161 after (59.85% remaining)
# Processed datadata_2017MagDown_1037.root: 304 events before, 182 after (59.87% remaining)
# Processed datadata_2017MagDown_1038.root: 282 events before, 159 after (56.38% remaining)
# Processed datadata_2017MagDown_1039.root: 353 events before, 199 after (56.37% remaining)
# Processed datadata_2017MagDown_104.root: 313 events before, 192 after (61.34% remaining)
# Processed datadata_2017MagDown_1040.root: 424 events before, 246 after (58.02% remaining)
# Processed datadata_2017MagDown_1041.root: 355 events before, 207 after (58.31% remaining)
# Processed datadata_2017MagDown_1042.root: 231 events before, 131 after (56.71% remaining)
# Processed datadata_2017MagDown_1043.root: 360 events before, 234 after (65.00% remaining)
# Processed datadata_2017MagDown_1044.root: 267 events before, 150 after (56.18% remaining)
# Processed datadata_2017MagDown_1045.root: 368 events before, 208 after (56.52% remaining)
# Processed datadata_2017MagDown_1046.root: 186 events before, 102 after (54.84% remaining)
# Processed datadata_2017MagDown_1047.root: 377 events before, 220 after (58.36% remaining)
# Processed datadata_2017MagDown_1048.root: 371 events before, 213 after (57.41% remaining)
# Processed datadata_2017MagDown_1049.root: 337 events before, 211 after (62.61% remaining)
# Processed datadata_2017MagDown_105.root: 340 events before, 214 after (62.94% remaining)
# Processed datadata_2017MagDown_1050.root: 307 events before, 179 after (58.31% remaining)
# Processed datadata_2017MagDown_1051.root: 250 events before, 154 after (61.60% remaining)
# Processed datadata_2017MagDown_1052.root: 341 events before, 208 after (61.00% remaining)
# Processed datadata_2017MagDown_1053.root: 306 events before, 196 after (64.05% remaining)
# Processed datadata_2017MagDown_1054.root: 304 events before, 179 after (58.88% remaining)
# Processed datadata_2017MagDown_1055.root: 312 events before, 200 after (64.10% remaining)
# Processed datadata_2017MagDown_1056.root: 390 events before, 234 after (60.00% remaining)
# Processed datadata_2017MagDown_1057.root: 341 events before, 207 after (60.70% remaining)
# Processed datadata_2017MagDown_1058.root: 305 events before, 194 after (63.61% remaining)
# Processed datadata_2017MagDown_1059.root: 416 events before, 249 after (59.86% remaining)
# Processed datadata_2017MagDown_106.root: 330 events before, 217 after (65.76% remaining)
# Processed datadata_2017MagDown_1060.root: 328 events before, 205 after (62.50% remaining)
# Processed datadata_2017MagDown_1061.root: 331 events before, 216 after (65.26% remaining)
# Processed datadata_2017MagDown_1062.root: 361 events before, 212 after (58.73% remaining)
# Processed datadata_2017MagDown_1063.root: 325 events before, 191 after (58.77% remaining)
# Processed datadata_2017MagDown_1064.root: 372 events before, 222 after (59.68% remaining)
# Processed datadata_2017MagDown_1065.root: 294 events before, 175 after (59.52% remaining)
# Processed datadata_2017MagDown_1066.root: 380 events before, 235 after (61.84% remaining)
# Processed datadata_2017MagDown_1067.root: 348 events before, 195 after (56.03% remaining)
# Processed datadata_2017MagDown_1068.root: 360 events before, 231 after (64.17% remaining)
# Processed datadata_2017MagDown_1069.root: 253 events before, 166 after (65.61% remaining)
# Processed datadata_2017MagDown_107.root: 387 events before, 233 after (60.21% remaining)
# Processed datadata_2017MagDown_1070.root: 376 events before, 242 after (64.36% remaining)
# Processed datadata_2017MagDown_1071.root: 342 events before, 207 after (60.53% remaining)
# Processed datadata_2017MagDown_1072.root: 367 events before, 224 after (61.04% remaining)
# Processed datadata_2017MagDown_1073.root: 274 events before, 180 after (65.69% remaining)
# Processed datadata_2017MagDown_1074.root: 348 events before, 226 after (64.94% remaining)
# Processed datadata_2017MagDown_1075.root: 408 events before, 250 after (61.27% remaining)
# Processed datadata_2017MagDown_1076.root: 374 events before, 230 after (61.50% remaining)
# Processed datadata_2017MagDown_1077.root: 332 events before, 207 after (62.35% remaining)
# Processed datadata_2017MagDown_1078.root: 243 events before, 138 after (56.79% remaining)
# Processed datadata_2017MagDown_1079.root: 318 events before, 191 after (60.06% remaining)
# Processed datadata_2017MagDown_108.root: 417 events before, 285 after (68.35% remaining)
# Processed datadata_2017MagDown_1080.root: 319 events before, 175 after (54.86% remaining)
# Processed datadata_2017MagDown_1081.root: 349 events before, 211 after (60.46% remaining)
# Processed datadata_2017MagDown_1082.root: 356 events before, 218 after (61.24% remaining)
# Processed datadata_2017MagDown_1083.root: 311 events before, 183 after (58.84% remaining)
# Processed datadata_2017MagDown_1084.root: 396 events before, 241 after (60.86% remaining)
# Processed datadata_2017MagDown_1085.root: 254 events before, 144 after (56.69% remaining)
# Processed datadata_2017MagDown_1086.root: 213 events before, 129 after (60.56% remaining)
# Processed datadata_2017MagDown_1087.root: 347 events before, 225 after (64.84% remaining)
# Processed datadata_2017MagDown_1088.root: 291 events before, 163 after (56.01% remaining)
# Processed datadata_2017MagDown_1089.root: 283 events before, 188 after (66.43% remaining)
# Processed datadata_2017MagDown_109.root: 405 events before, 241 after (59.51% remaining)
# Processed datadata_2017MagDown_1090.root: 294 events before, 183 after (62.24% remaining)
# Processed datadata_2017MagDown_1091.root: 298 events before, 164 after (55.03% remaining)
# Processed datadata_2017MagDown_1092.root: 226 events before, 122 after (53.98% remaining)
# Processed datadata_2017MagDown_1093.root: 319 events before, 185 after (57.99% remaining)
# Processed datadata_2017MagDown_1094.root: 225 events before, 135 after (60.00% remaining)
# Processed datadata_2017MagDown_1095.root: 249 events before, 146 after (58.63% remaining)
# Processed datadata_2017MagDown_1096.root: 229 events before, 155 after (67.69% remaining)
# Processed datadata_2017MagDown_1097.root: 331 events before, 184 after (55.59% remaining)
# Processed datadata_2017MagDown_1098.root: 262 events before, 150 after (57.25% remaining)
# Processed datadata_2017MagDown_1099.root: 217 events before, 133 after (61.29% remaining)
# Processed datadata_2017MagDown_11.root: 436 events before, 249 after (57.11% remaining)
# Processed datadata_2017MagDown_110.root: 328 events before, 216 after (65.85% remaining)
# Processed datadata_2017MagDown_1100.root: 257 events before, 155 after (60.31% remaining)
# Processed datadata_2017MagDown_1101.root: 278 events before, 167 after (60.07% remaining)
# Processed datadata_2017MagDown_1102.root: 242 events before, 142 after (58.68% remaining)
# Processed datadata_2017MagDown_1103.root: 280 events before, 156 after (55.71% remaining)
# Processed datadata_2017MagDown_1104.root: 260 events before, 164 after (63.08% remaining)
# Processed datadata_2017MagDown_1105.root: 264 events before, 163 after (61.74% remaining)
# Processed datadata_2017MagDown_1106.root: 283 events before, 176 after (62.19% remaining)
# Processed datadata_2017MagDown_1107.root: 283 events before, 166 after (58.66% remaining)
# Processed datadata_2017MagDown_1108.root: 315 events before, 187 after (59.37% remaining)
# Processed datadata_2017MagDown_1109.root: 309 events before, 184 after (59.55% remaining)
# Processed datadata_2017MagDown_111.root: 385 events before, 244 after (63.38% remaining)
# Processed datadata_2017MagDown_1110.root: 284 events before, 166 after (58.45% remaining)
# Processed datadata_2017MagDown_1111.root: 294 events before, 169 after (57.48% remaining)
# Processed datadata_2017MagDown_1112.root: 255 events before, 142 after (55.69% remaining)
# Processed datadata_2017MagDown_1113.root: 238 events before, 145 after (60.92% remaining)
# Processed datadata_2017MagDown_1114.root: 236 events before, 146 after (61.86% remaining)
# Processed datadata_2017MagDown_1115.root: 289 events before, 175 after (60.55% remaining)
# Processed datadata_2017MagDown_1116.root: 298 events before, 190 after (63.76% remaining)
# Processed datadata_2017MagDown_1117.root: 302 events before, 183 after (60.60% remaining)
# Processed datadata_2017MagDown_1118.root: 277 events before, 189 after (68.23% remaining)
# Processed datadata_2017MagDown_1119.root: 222 events before, 114 after (51.35% remaining)
# Processed datadata_2017MagDown_112.root: 317 events before, 182 after (57.41% remaining)
# Processed datadata_2017MagDown_1120.root: 255 events before, 159 after (62.35% remaining)
# Processed datadata_2017MagDown_1121.root: 284 events before, 185 after (65.14% remaining)
# Processed datadata_2017MagDown_1122.root: 244 events before, 149 after (61.07% remaining)
# Processed datadata_2017MagDown_1123.root: 293 events before, 184 after (62.80% remaining)
# Processed datadata_2017MagDown_1124.root: 257 events before, 154 after (59.92% remaining)
# Processed datadata_2017MagDown_1125.root: 217 events before, 127 after (58.53% remaining)
# Processed datadata_2017MagDown_1126.root: 217 events before, 136 after (62.67% remaining)
# Processed datadata_2017MagDown_1127.root: 181 events before, 117 after (64.64% remaining)
# Processed datadata_2017MagDown_1128.root: 265 events before, 168 after (63.40% remaining)
# Processed datadata_2017MagDown_1129.root: 309 events before, 170 after (55.02% remaining)
# Processed datadata_2017MagDown_113.root: 393 events before, 220 after (55.98% remaining)
# Processed datadata_2017MagDown_1130.root: 265 events before, 147 after (55.47% remaining)
# Processed datadata_2017MagDown_1131.root: 219 events before, 128 after (58.45% remaining)
# Processed datadata_2017MagDown_1132.root: 273 events before, 163 after (59.71% remaining)
# Processed datadata_2017MagDown_1133.root: 275 events before, 185 after (67.27% remaining)
# Processed datadata_2017MagDown_1134.root: 246 events before, 138 after (56.10% remaining)
# Processed datadata_2017MagDown_1135.root: 291 events before, 166 after (57.04% remaining)
# Processed datadata_2017MagDown_1136.root: 328 events before, 189 after (57.62% remaining)
# Processed datadata_2017MagDown_1137.root: 251 events before, 155 after (61.75% remaining)
# Processed datadata_2017MagDown_1138.root: 304 events before, 175 after (57.57% remaining)
# Processed datadata_2017MagDown_1139.root: 270 events before, 178 after (65.93% remaining)
# Processed datadata_2017MagDown_114.root: 363 events before, 219 after (60.33% remaining)
# Processed datadata_2017MagDown_1140.root: 282 events before, 170 after (60.28% remaining)
# Processed datadata_2017MagDown_1141.root: 257 events before, 160 after (62.26% remaining)
# Processed datadata_2017MagDown_1142.root: 247 events before, 135 after (54.66% remaining)
# Processed datadata_2017MagDown_1143.root: 175 events before, 103 after (58.86% remaining)
# Processed datadata_2017MagDown_1144.root: 284 events before, 167 after (58.80% remaining)
# Processed datadata_2017MagDown_1145.root: 283 events before, 173 after (61.13% remaining)
# Processed datadata_2017MagDown_1146.root: 269 events before, 176 after (65.43% remaining)
# Processed datadata_2017MagDown_1147.root: 267 events before, 168 after (62.92% remaining)
# Processed datadata_2017MagDown_1148.root: 261 events before, 171 after (65.52% remaining)
# Processed datadata_2017MagDown_1149.root: 316 events before, 172 after (54.43% remaining)
# Processed datadata_2017MagDown_115.root: 358 events before, 213 after (59.50% remaining)
# Processed datadata_2017MagDown_1150.root: 256 events before, 159 after (62.11% remaining)
# Processed datadata_2017MagDown_1151.root: 312 events before, 179 after (57.37% remaining)
# Processed datadata_2017MagDown_1152.root: 262 events before, 157 after (59.92% remaining)
# Processed datadata_2017MagDown_1153.root: 257 events before, 174 after (67.70% remaining)
# Processed datadata_2017MagDown_1154.root: 276 events before, 177 after (64.13% remaining)
# Processed datadata_2017MagDown_1155.root: 210 events before, 127 after (60.48% remaining)
# Processed datadata_2017MagDown_1156.root: 309 events before, 194 after (62.78% remaining)
# Processed datadata_2017MagDown_1157.root: 278 events before, 179 after (64.39% remaining)
# Processed datadata_2017MagDown_1158.root: 270 events before, 157 after (58.15% remaining)
# Processed datadata_2017MagDown_1159.root: 273 events before, 166 after (60.81% remaining)
# Processed datadata_2017MagDown_116.root: 347 events before, 220 after (63.40% remaining)
# Processed datadata_2017MagDown_1160.root: 265 events before, 160 after (60.38% remaining)
# Processed datadata_2017MagDown_1161.root: 237 events before, 148 after (62.45% remaining)
# Processed datadata_2017MagDown_1162.root: 259 events before, 146 after (56.37% remaining)
# Processed datadata_2017MagDown_1163.root: 266 events before, 150 after (56.39% remaining)
# Processed datadata_2017MagDown_1164.root: 210 events before, 117 after (55.71% remaining)
# Processed datadata_2017MagDown_1165.root: 241 events before, 133 after (55.19% remaining)
# Processed datadata_2017MagDown_1166.root: 253 events before, 148 after (58.50% remaining)
# Processed datadata_2017MagDown_1167.root: 258 events before, 166 after (64.34% remaining)
# Processed datadata_2017MagDown_1168.root: 285 events before, 146 after (51.23% remaining)
# Processed datadata_2017MagDown_1169.root: 307 events before, 179 after (58.31% remaining)
# Processed datadata_2017MagDown_117.root: 259 events before, 169 after (65.25% remaining)
# Processed datadata_2017MagDown_1170.root: 295 events before, 180 after (61.02% remaining)
# Processed datadata_2017MagDown_1171.root: 240 events before, 128 after (53.33% remaining)
# Processed datadata_2017MagDown_1172.root: 256 events before, 139 after (54.30% remaining)
# Processed datadata_2017MagDown_1173.root: 273 events before, 173 after (63.37% remaining)
# Processed datadata_2017MagDown_1174.root: 315 events before, 188 after (59.68% remaining)
# Processed datadata_2017MagDown_1175.root: 268 events before, 165 after (61.57% remaining)
# Processed datadata_2017MagDown_1176.root: 309 events before, 174 after (56.31% remaining)
# Processed datadata_2017MagDown_1177.root: 315 events before, 197 after (62.54% remaining)
# Processed datadata_2017MagDown_1178.root: 258 events before, 163 after (63.18% remaining)
# Processed datadata_2017MagDown_1179.root: 242 events before, 128 after (52.89% remaining)
# Processed datadata_2017MagDown_118.root: 334 events before, 196 after (58.68% remaining)
# Processed datadata_2017MagDown_1180.root: 258 events before, 153 after (59.30% remaining)
# Processed datadata_2017MagDown_1181.root: 254 events before, 161 after (63.39% remaining)
# Processed datadata_2017MagDown_1182.root: 255 events before, 149 after (58.43% remaining)
# Processed datadata_2017MagDown_1183.root: 243 events before, 150 after (61.73% remaining)
# Processed datadata_2017MagDown_1184.root: 266 events before, 160 after (60.15% remaining)
# Processed datadata_2017MagDown_1185.root: 255 events before, 157 after (61.57% remaining)
# Processed datadata_2017MagDown_1186.root: 226 events before, 127 after (56.19% remaining)
# Processed datadata_2017MagDown_1187.root: 249 events before, 149 after (59.84% remaining)
# Processed datadata_2017MagDown_1188.root: 249 events before, 143 after (57.43% remaining)
# Processed datadata_2017MagDown_1189.root: 236 events before, 131 after (55.51% remaining)
# Processed datadata_2017MagDown_119.root: 335 events before, 201 after (60.00% remaining)
# Processed datadata_2017MagDown_1190.root: 273 events before, 142 after (52.01% remaining)
# Processed datadata_2017MagDown_1191.root: 223 events before, 145 after (65.02% remaining)
# Processed datadata_2017MagDown_1192.root: 266 events before, 158 after (59.40% remaining)
# Processed datadata_2017MagDown_1193.root: 276 events before, 176 after (63.77% remaining)
# Processed datadata_2017MagDown_1194.root: 307 events before, 182 after (59.28% remaining)
# Processed datadata_2017MagDown_1195.root: 173 events before, 103 after (59.54% remaining)
# Processed datadata_2017MagDown_1196.root: 304 events before, 189 after (62.17% remaining)
# Processed datadata_2017MagDown_1197.root: 288 events before, 173 after (60.07% remaining)
# Processed datadata_2017MagDown_1198.root: 298 events before, 189 after (63.42% remaining)
# Processed datadata_2017MagDown_1199.root: 283 events before, 159 after (56.18% remaining)
# Processed datadata_2017MagDown_12.root: 382 events before, 235 after (61.52% remaining)
# Processed datadata_2017MagDown_120.root: 393 events before, 246 after (62.60% remaining)
# Processed datadata_2017MagDown_1200.root: 270 events before, 156 after (57.78% remaining)
# Processed datadata_2017MagDown_1201.root: 260 events before, 144 after (55.38% remaining)
# Processed datadata_2017MagDown_1202.root: 247 events before, 153 after (61.94% remaining)
# Processed datadata_2017MagDown_1203.root: 289 events before, 169 after (58.48% remaining)
# Processed datadata_2017MagDown_1204.root: 272 events before, 158 after (58.09% remaining)
# Processed datadata_2017MagDown_1205.root: 230 events before, 143 after (62.17% remaining)
# Processed datadata_2017MagDown_1206.root: 237 events before, 143 after (60.34% remaining)
# Processed datadata_2017MagDown_1207.root: 224 events before, 140 after (62.50% remaining)
# Processed datadata_2017MagDown_1208.root: 268 events before, 154 after (57.46% remaining)
# Processed datadata_2017MagDown_1209.root: 286 events before, 168 after (58.74% remaining)
# Processed datadata_2017MagDown_121.root: 288 events before, 174 after (60.42% remaining)
# Processed datadata_2017MagDown_1210.root: 298 events before, 182 after (61.07% remaining)
# Processed datadata_2017MagDown_1211.root: 211 events before, 136 after (64.45% remaining)
# Processed datadata_2017MagDown_1212.root: 234 events before, 125 after (53.42% remaining)
# Processed datadata_2017MagDown_1213.root: 267 events before, 168 after (62.92% remaining)
# Processed datadata_2017MagDown_1214.root: 264 events before, 152 after (57.58% remaining)
# Processed datadata_2017MagDown_1215.root: 253 events before, 143 after (56.52% remaining)
# Processed datadata_2017MagDown_1216.root: 276 events before, 164 after (59.42% remaining)
# Processed datadata_2017MagDown_1217.root: 290 events before, 183 after (63.10% remaining)
# Processed datadata_2017MagDown_1218.root: 198 events before, 117 after (59.09% remaining)
# Processed datadata_2017MagDown_1219.root: 267 events before, 160 after (59.93% remaining)
# Processed datadata_2017MagDown_122.root: 294 events before, 169 after (57.48% remaining)
# Processed datadata_2017MagDown_1220.root: 329 events before, 193 after (58.66% remaining)
# Processed datadata_2017MagDown_1221.root: 309 events before, 166 after (53.72% remaining)
# Processed datadata_2017MagDown_1222.root: 309 events before, 174 after (56.31% remaining)
# Processed datadata_2017MagDown_1223.root: 305 events before, 191 after (62.62% remaining)
# Processed datadata_2017MagDown_1224.root: 272 events before, 165 after (60.66% remaining)
# Processed datadata_2017MagDown_1225.root: 296 events before, 187 after (63.18% remaining)
# Processed datadata_2017MagDown_1226.root: 290 events before, 176 after (60.69% remaining)
# Processed datadata_2017MagDown_1227.root: 310 events before, 176 after (56.77% remaining)
# Processed datadata_2017MagDown_1228.root: 269 events before, 162 after (60.22% remaining)
# Processed datadata_2017MagDown_1229.root: 184 events before, 102 after (55.43% remaining)
# Processed datadata_2017MagDown_123.root: 355 events before, 221 after (62.25% remaining)
# Processed datadata_2017MagDown_1230.root: 216 events before, 128 after (59.26% remaining)
# Processed datadata_2017MagDown_1231.root: 278 events before, 170 after (61.15% remaining)
# Processed datadata_2017MagDown_1232.root: 262 events before, 155 after (59.16% remaining)
# Processed datadata_2017MagDown_1233.root: 234 events before, 140 after (59.83% remaining)
# Processed datadata_2017MagDown_1234.root: 235 events before, 142 after (60.43% remaining)
# Processed datadata_2017MagDown_1235.root: 290 events before, 172 after (59.31% remaining)
# Processed datadata_2017MagDown_1236.root: 320 events before, 215 after (67.19% remaining)
# Processed datadata_2017MagDown_1237.root: 203 events before, 119 after (58.62% remaining)
# Processed datadata_2017MagDown_1238.root: 232 events before, 133 after (57.33% remaining)
# Processed datadata_2017MagDown_1239.root: 289 events before, 166 after (57.44% remaining)
# Processed datadata_2017MagDown_124.root: 401 events before, 231 after (57.61% remaining)
# Processed datadata_2017MagDown_1240.root: 244 events before, 163 after (66.80% remaining)
# Processed datadata_2017MagDown_1241.root: 291 events before, 188 after (64.60% remaining)
# Processed datadata_2017MagDown_1242.root: 218 events before, 130 after (59.63% remaining)
# Processed datadata_2017MagDown_1243.root: 233 events before, 146 after (62.66% remaining)
# Processed datadata_2017MagDown_1244.root: 307 events before, 191 after (62.21% remaining)
# Processed datadata_2017MagDown_1245.root: 276 events before, 173 after (62.68% remaining)
# Processed datadata_2017MagDown_1246.root: 238 events before, 160 after (67.23% remaining)
# Processed datadata_2017MagDown_1247.root: 292 events before, 165 after (56.51% remaining)
# Processed datadata_2017MagDown_1248.root: 272 events before, 166 after (61.03% remaining)
# Processed datadata_2017MagDown_1249.root: 228 events before, 132 after (57.89% remaining)
# Processed datadata_2017MagDown_125.root: 440 events before, 268 after (60.91% remaining)
# Processed datadata_2017MagDown_1250.root: 267 events before, 163 after (61.05% remaining)
# Processed datadata_2017MagDown_1251.root: 276 events before, 188 after (68.12% remaining)
# Processed datadata_2017MagDown_1252.root: 286 events before, 175 after (61.19% remaining)
# Processed datadata_2017MagDown_1253.root: 308 events before, 186 after (60.39% remaining)
# Processed datadata_2017MagDown_1254.root: 235 events before, 135 after (57.45% remaining)
# Processed datadata_2017MagDown_1255.root: 279 events before, 152 after (54.48% remaining)
# Processed datadata_2017MagDown_1256.root: 286 events before, 168 after (58.74% remaining)
# Processed datadata_2017MagDown_1257.root: 278 events before, 157 after (56.47% remaining)
# Processed datadata_2017MagDown_1258.root: 282 events before, 173 after (61.35% remaining)
# Processed datadata_2017MagDown_1259.root: 299 events before, 196 after (65.55% remaining)
# Processed datadata_2017MagDown_126.root: 390 events before, 224 after (57.44% remaining)
# Processed datadata_2017MagDown_1260.root: 247 events before, 159 after (64.37% remaining)
# Processed datadata_2017MagDown_1261.root: 261 events before, 167 after (63.98% remaining)
# Processed datadata_2017MagDown_1262.root: 132 events before, 80 after (60.61% remaining)
# Processed datadata_2017MagDown_1263.root: 288 events before, 182 after (63.19% remaining)
# Processed datadata_2017MagDown_1264.root: 287 events before, 178 after (62.02% remaining)
# Processed datadata_2017MagDown_1265.root: 250 events before, 153 after (61.20% remaining)
# Processed datadata_2017MagDown_1266.root: 324 events before, 171 after (52.78% remaining)
# Processed datadata_2017MagDown_1267.root: 235 events before, 145 after (61.70% remaining)
# Processed datadata_2017MagDown_1268.root: 287 events before, 159 after (55.40% remaining)
# Processed datadata_2017MagDown_1269.root: 175 events before, 115 after (65.71% remaining)
# Processed datadata_2017MagDown_127.root: 405 events before, 257 after (63.46% remaining)
# Processed datadata_2017MagDown_1270.root: 242 events before, 145 after (59.92% remaining)
# Processed datadata_2017MagDown_1271.root: 263 events before, 155 after (58.94% remaining)
# Processed datadata_2017MagDown_1272.root: 246 events before, 153 after (62.20% remaining)
# Processed datadata_2017MagDown_1273.root: 273 events before, 175 after (64.10% remaining)
# Processed datadata_2017MagDown_1274.root: 293 events before, 172 after (58.70% remaining)
# Processed datadata_2017MagDown_1275.root: 330 events before, 211 after (63.94% remaining)
# Processed datadata_2017MagDown_1276.root: 287 events before, 181 after (63.07% remaining)
# Processed datadata_2017MagDown_1277.root: 237 events before, 143 after (60.34% remaining)
# Processed datadata_2017MagDown_1278.root: 256 events before, 158 after (61.72% remaining)
# Processed datadata_2017MagDown_1279.root: 259 events before, 144 after (55.60% remaining)
# Processed datadata_2017MagDown_128.root: 378 events before, 231 after (61.11% remaining)
# Processed datadata_2017MagDown_1280.root: 256 events before, 132 after (51.56% remaining)
# Processed datadata_2017MagDown_1281.root: 281 events before, 168 after (59.79% remaining)
# Processed datadata_2017MagDown_1282.root: 258 events before, 148 after (57.36% remaining)
# Processed datadata_2017MagDown_1283.root: 267 events before, 154 after (57.68% remaining)
# Processed datadata_2017MagDown_1284.root: 296 events before, 173 after (58.45% remaining)
# Processed datadata_2017MagDown_1285.root: 196 events before, 120 after (61.22% remaining)
# Processed datadata_2017MagDown_1286.root: 276 events before, 173 after (62.68% remaining)
# Processed datadata_2017MagDown_1287.root: 268 events before, 167 after (62.31% remaining)
# Processed datadata_2017MagDown_1288.root: 259 events before, 142 after (54.83% remaining)
# Processed datadata_2017MagDown_1289.root: 300 events before, 180 after (60.00% remaining)
# Processed datadata_2017MagDown_129.root: 340 events before, 205 after (60.29% remaining)
# Processed datadata_2017MagDown_1290.root: 193 events before, 104 after (53.89% remaining)
# Processed datadata_2017MagDown_1291.root: 227 events before, 132 after (58.15% remaining)
# Processed datadata_2017MagDown_1292.root: 233 events before, 153 after (65.67% remaining)
# Processed datadata_2017MagDown_1293.root: 297 events before, 186 after (62.63% remaining)
# Processed datadata_2017MagDown_1294.root: 226 events before, 135 after (59.73% remaining)
# Processed datadata_2017MagDown_1295.root: 251 events before, 147 after (58.57% remaining)
# Processed datadata_2017MagDown_1296.root: 295 events before, 181 after (61.36% remaining)
# Processed datadata_2017MagDown_1297.root: 281 events before, 170 after (60.50% remaining)
# Processed datadata_2017MagDown_1298.root: 218 events before, 130 after (59.63% remaining)
# Processed datadata_2017MagDown_1299.root: 263 events before, 173 after (65.78% remaining)
# Processed datadata_2017MagDown_13.root: 256 events before, 145 after (56.64% remaining)
# Processed datadata_2017MagDown_130.root: 322 events before, 206 after (63.98% remaining)
# Processed datadata_2017MagDown_1300.root: 223 events before, 132 after (59.19% remaining)
# Processed datadata_2017MagDown_1301.root: 246 events before, 155 after (63.01% remaining)
# Processed datadata_2017MagDown_1302.root: 280 events before, 170 after (60.71% remaining)
# Processed datadata_2017MagDown_1303.root: 297 events before, 184 after (61.95% remaining)
# Processed datadata_2017MagDown_1304.root: 323 events before, 181 after (56.04% remaining)
# Processed datadata_2017MagDown_1305.root: 318 events before, 200 after (62.89% remaining)
# Processed datadata_2017MagDown_1306.root: 272 events before, 164 after (60.29% remaining)
# Processed datadata_2017MagDown_1307.root: 293 events before, 159 after (54.27% remaining)
# Processed datadata_2017MagDown_1308.root: 270 events before, 165 after (61.11% remaining)
# Processed datadata_2017MagDown_1309.root: 293 events before, 158 after (53.92% remaining)
# Processed datadata_2017MagDown_131.root: 310 events before, 195 after (62.90% remaining)
# Processed datadata_2017MagDown_1310.root: 323 events before, 193 after (59.75% remaining)
# Processed datadata_2017MagDown_1311.root: 267 events before, 154 after (57.68% remaining)
# Processed datadata_2017MagDown_1312.root: 279 events before, 168 after (60.22% remaining)
# Processed datadata_2017MagDown_1313.root: 232 events before, 153 after (65.95% remaining)
# Processed datadata_2017MagDown_1314.root: 273 events before, 168 after (61.54% remaining)
# Processed datadata_2017MagDown_1315.root: 278 events before, 149 after (53.60% remaining)
# Processed datadata_2017MagDown_1316.root: 288 events before, 160 after (55.56% remaining)
# Processed datadata_2017MagDown_1317.root: 221 events before, 138 after (62.44% remaining)
# Processed datadata_2017MagDown_1318.root: 296 events before, 156 after (52.70% remaining)
# Processed datadata_2017MagDown_1319.root: 197 events before, 117 after (59.39% remaining)
# Processed datadata_2017MagDown_132.root: 351 events before, 197 after (56.13% remaining)
# Processed datadata_2017MagDown_1320.root: 271 events before, 168 after (61.99% remaining)
# Processed datadata_2017MagDown_1321.root: 277 events before, 153 after (55.23% remaining)
# Processed datadata_2017MagDown_1322.root: 231 events before, 141 after (61.04% remaining)
# Processed datadata_2017MagDown_1323.root: 180 events before, 101 after (56.11% remaining)
# Processed datadata_2017MagDown_1324.root: 229 events before, 128 after (55.90% remaining)
# Processed datadata_2017MagDown_1325.root: 243 events before, 136 after (55.97% remaining)
# Processed datadata_2017MagDown_1326.root: 301 events before, 166 after (55.15% remaining)
# Processed datadata_2017MagDown_1327.root: 306 events before, 180 after (58.82% remaining)
# Processed datadata_2017MagDown_1328.root: 274 events before, 175 after (63.87% remaining)
# Processed datadata_2017MagDown_1329.root: 201 events before, 122 after (60.70% remaining)
# Processed datadata_2017MagDown_133.root: 376 events before, 220 after (58.51% remaining)
# Processed datadata_2017MagDown_1330.root: 314 events before, 207 after (65.92% remaining)
# Processed datadata_2017MagDown_1331.root: 267 events before, 154 after (57.68% remaining)
# Processed datadata_2017MagDown_1332.root: 241 events before, 133 after (55.19% remaining)
# Processed datadata_2017MagDown_1333.root: 298 events before, 185 after (62.08% remaining)
# Processed datadata_2017MagDown_1334.root: 340 events before, 206 after (60.59% remaining)
# Processed datadata_2017MagDown_1335.root: 246 events before, 162 after (65.85% remaining)
# Processed datadata_2017MagDown_1336.root: 271 events before, 168 after (61.99% remaining)
# Processed datadata_2017MagDown_1337.root: 276 events before, 167 after (60.51% remaining)
# Processed datadata_2017MagDown_1338.root: 296 events before, 176 after (59.46% remaining)
# Processed datadata_2017MagDown_1339.root: 311 events before, 195 after (62.70% remaining)
# Processed datadata_2017MagDown_134.root: 347 events before, 226 after (65.13% remaining)
# Processed datadata_2017MagDown_1340.root: 259 events before, 162 after (62.55% remaining)
# Processed datadata_2017MagDown_1341.root: 273 events before, 172 after (63.00% remaining)
# Processed datadata_2017MagDown_1342.root: 249 events before, 142 after (57.03% remaining)
# Processed datadata_2017MagDown_1343.root: 266 events before, 174 after (65.41% remaining)
# Processed datadata_2017MagDown_1344.root: 273 events before, 167 after (61.17% remaining)
# Processed datadata_2017MagDown_1345.root: 284 events before, 161 after (56.69% remaining)
# Processed datadata_2017MagDown_1346.root: 228 events before, 144 after (63.16% remaining)
# Processed datadata_2017MagDown_1347.root: 224 events before, 121 after (54.02% remaining)
# Processed datadata_2017MagDown_1348.root: 314 events before, 182 after (57.96% remaining)
# Processed datadata_2017MagDown_1349.root: 234 events before, 131 after (55.98% remaining)
# Processed datadata_2017MagDown_135.root: 307 events before, 194 after (63.19% remaining)
# Processed datadata_2017MagDown_1350.root: 225 events before, 135 after (60.00% remaining)
# Processed datadata_2017MagDown_1351.root: 282 events before, 161 after (57.09% remaining)
# Processed datadata_2017MagDown_1352.root: 230 events before, 141 after (61.30% remaining)
# Processed datadata_2017MagDown_1353.root: 220 events before, 135 after (61.36% remaining)
# Processed datadata_2017MagDown_1354.root: 320 events before, 214 after (66.88% remaining)
# Processed datadata_2017MagDown_1355.root: 263 events before, 151 after (57.41% remaining)
# Processed datadata_2017MagDown_1356.root: 262 events before, 161 after (61.45% remaining)
# Processed datadata_2017MagDown_1357.root: 313 events before, 185 after (59.11% remaining)
# Processed datadata_2017MagDown_1358.root: 307 events before, 175 after (57.00% remaining)
# Processed datadata_2017MagDown_1359.root: 277 events before, 165 after (59.57% remaining)
# Processed datadata_2017MagDown_136.root: 342 events before, 217 after (63.45% remaining)
# Processed datadata_2017MagDown_1360.root: 301 events before, 175 after (58.14% remaining)
# Processed datadata_2017MagDown_1361.root: 214 events before, 119 after (55.61% remaining)
# Processed datadata_2017MagDown_1362.root: 225 events before, 138 after (61.33% remaining)
# Processed datadata_2017MagDown_1363.root: 194 events before, 117 after (60.31% remaining)
# Processed datadata_2017MagDown_1364.root: 249 events before, 153 after (61.45% remaining)
# Processed datadata_2017MagDown_1365.root: 235 events before, 149 after (63.40% remaining)
# Processed datadata_2017MagDown_1366.root: 263 events before, 170 after (64.64% remaining)
# Processed datadata_2017MagDown_1367.root: 273 events before, 184 after (67.40% remaining)
# Processed datadata_2017MagDown_1368.root: 204 events before, 117 after (57.35% remaining)
# Processed datadata_2017MagDown_1369.root: 260 events before, 157 after (60.38% remaining)
# Processed datadata_2017MagDown_137.root: 432 events before, 252 after (58.33% remaining)
# Processed datadata_2017MagDown_1370.root: 243 events before, 151 after (62.14% remaining)
# Processed datadata_2017MagDown_1371.root: 317 events before, 189 after (59.62% remaining)
# Processed datadata_2017MagDown_1372.root: 239 events before, 142 after (59.41% remaining)
# Processed datadata_2017MagDown_1373.root: 292 events before, 172 after (58.90% remaining)
# Processed datadata_2017MagDown_1374.root: 296 events before, 167 after (56.42% remaining)
# Processed datadata_2017MagDown_1375.root: 240 events before, 149 after (62.08% remaining)
# Processed datadata_2017MagDown_1376.root: 239 events before, 145 after (60.67% remaining)
# Processed datadata_2017MagDown_1377.root: 291 events before, 173 after (59.45% remaining)
# Processed datadata_2017MagDown_1378.root: 296 events before, 179 after (60.47% remaining)
# Processed datadata_2017MagDown_1379.root: 260 events before, 162 after (62.31% remaining)
# Processed datadata_2017MagDown_138.root: 324 events before, 202 after (62.35% remaining)
# Processed datadata_2017MagDown_1380.root: 266 events before, 142 after (53.38% remaining)
# Processed datadata_2017MagDown_1381.root: 291 events before, 166 after (57.04% remaining)
# Processed datadata_2017MagDown_1382.root: 364 events before, 208 after (57.14% remaining)
# Processed datadata_2017MagDown_1383.root: 238 events before, 144 after (60.50% remaining)
# Processed datadata_2017MagDown_1384.root: 288 events before, 177 after (61.46% remaining)
# Processed datadata_2017MagDown_1385.root: 270 events before, 162 after (60.00% remaining)
# Processed datadata_2017MagDown_1386.root: 274 events before, 176 after (64.23% remaining)
# Processed datadata_2017MagDown_1387.root: 218 events before, 139 after (63.76% remaining)
# Processed datadata_2017MagDown_1388.root: 233 events before, 142 after (60.94% remaining)
# Processed datadata_2017MagDown_1389.root: 249 events before, 152 after (61.04% remaining)
# Processed datadata_2017MagDown_139.root: 361 events before, 220 after (60.94% remaining)
# Processed datadata_2017MagDown_1390.root: 107 events before, 65 after (60.75% remaining)
# Processed datadata_2017MagDown_1391.root: 268 events before, 163 after (60.82% remaining)
# Processed datadata_2017MagDown_1392.root: 308 events before, 175 after (56.82% remaining)
# Processed datadata_2017MagDown_1393.root: 267 events before, 148 after (55.43% remaining)
# Processed datadata_2017MagDown_1394.root: 275 events before, 175 after (63.64% remaining)
# Processed datadata_2017MagDown_1395.root: 229 events before, 125 after (54.59% remaining)
# Processed datadata_2017MagDown_1396.root: 261 events before, 141 after (54.02% remaining)
# Processed datadata_2017MagDown_1397.root: 323 events before, 209 after (64.71% remaining)
# Processed datadata_2017MagDown_1398.root: 290 events before, 179 after (61.72% remaining)
# Processed datadata_2017MagDown_1399.root: 180 events before, 108 after (60.00% remaining)
# Processed datadata_2017MagDown_14.root: 479 events before, 288 after (60.13% remaining)
# Processed datadata_2017MagDown_140.root: 349 events before, 205 after (58.74% remaining)
# Processed datadata_2017MagDown_1400.root: 273 events before, 162 after (59.34% remaining)
# Processed datadata_2017MagDown_1401.root: 288 events before, 175 after (60.76% remaining)
# Processed datadata_2017MagDown_1402.root: 255 events before, 151 after (59.22% remaining)
# Processed datadata_2017MagDown_1403.root: 197 events before, 122 after (61.93% remaining)
# Processed datadata_2017MagDown_1404.root: 316 events before, 189 after (59.81% remaining)
# Processed datadata_2017MagDown_1405.root: 266 events before, 161 after (60.53% remaining)
# Processed datadata_2017MagDown_1406.root: 268 events before, 156 after (58.21% remaining)
# Processed datadata_2017MagDown_1407.root: 244 events before, 153 after (62.70% remaining)
# Processed datadata_2017MagDown_1408.root: 250 events before, 159 after (63.60% remaining)
# Processed datadata_2017MagDown_1409.root: 234 events before, 147 after (62.82% remaining)
# Processed datadata_2017MagDown_141.root: 352 events before, 202 after (57.39% remaining)
# Processed datadata_2017MagDown_1410.root: 271 events before, 159 after (58.67% remaining)
# Processed datadata_2017MagDown_1411.root: 249 events before, 167 after (67.07% remaining)
# Processed datadata_2017MagDown_1412.root: 161 events before, 95 after (59.01% remaining)
# Processed datadata_2017MagDown_1413.root: 315 events before, 188 after (59.68% remaining)
# Processed datadata_2017MagDown_1414.root: 196 events before, 110 after (56.12% remaining)
# Processed datadata_2017MagDown_1415.root: 248 events before, 144 after (58.06% remaining)
# Processed datadata_2017MagDown_1416.root: 134 events before, 80 after (59.70% remaining)
# Processed datadata_2017MagDown_1417.root: 253 events before, 160 after (63.24% remaining)
# Processed datadata_2017MagDown_1418.root: 180 events before, 111 after (61.67% remaining)
# Processed datadata_2017MagDown_1419.root: 275 events before, 182 after (66.18% remaining)
# Processed datadata_2017MagDown_142.root: 229 events before, 138 after (60.26% remaining)
# Processed datadata_2017MagDown_1420.root: 267 events before, 158 after (59.18% remaining)
# Processed datadata_2017MagDown_1421.root: 170 events before, 103 after (60.59% remaining)
# Processed datadata_2017MagDown_1422.root: 236 events before, 128 after (54.24% remaining)
# Processed datadata_2017MagDown_1423.root: 219 events before, 128 after (58.45% remaining)
# Processed datadata_2017MagDown_1424.root: 240 events before, 153 after (63.75% remaining)
# Processed datadata_2017MagDown_1425.root: 265 events before, 160 after (60.38% remaining)
# Processed datadata_2017MagDown_1426.root: 180 events before, 100 after (55.56% remaining)
# Processed datadata_2017MagDown_1427.root: 191 events before, 123 after (64.40% remaining)
# Processed datadata_2017MagDown_1428.root: 227 events before, 137 after (60.35% remaining)
# Processed datadata_2017MagDown_1429.root: 264 events before, 157 after (59.47% remaining)
# Processed datadata_2017MagDown_143.root: 361 events before, 216 after (59.83% remaining)
# Processed datadata_2017MagDown_1430.root: 145 events before, 91 after (62.76% remaining)
# Processed datadata_2017MagDown_1431.root: 50 events before, 32 after (64.00% remaining)
# Processed datadata_2017MagDown_1432.root: 61 events before, 39 after (63.93% remaining)
# Processed datadata_2017MagDown_1433.root: 26 events before, 15 after (57.69% remaining)
# Processed datadata_2017MagDown_144.root: 386 events before, 265 after (68.65% remaining)
# Processed datadata_2017MagDown_145.root: 321 events before, 205 after (63.86% remaining)
# Processed datadata_2017MagDown_146.root: 351 events before, 216 after (61.54% remaining)
# Processed datadata_2017MagDown_147.root: 343 events before, 214 after (62.39% remaining)
# Processed datadata_2017MagDown_148.root: 403 events before, 237 after (58.81% remaining)
# Processed datadata_2017MagDown_149.root: 402 events before, 247 after (61.44% remaining)
# Processed datadata_2017MagDown_15.root: 368 events before, 223 after (60.60% remaining)
# Processed datadata_2017MagDown_150.root: 353 events before, 207 after (58.64% remaining)
# Processed datadata_2017MagDown_151.root: 306 events before, 188 after (61.44% remaining)
# Processed datadata_2017MagDown_152.root: 383 events before, 236 after (61.62% remaining)
# Processed datadata_2017MagDown_153.root: 320 events before, 196 after (61.25% remaining)
# Processed datadata_2017MagDown_154.root: 313 events before, 183 after (58.47% remaining)
# Processed datadata_2017MagDown_155.root: 347 events before, 198 after (57.06% remaining)
# Processed datadata_2017MagDown_156.root: 345 events before, 204 after (59.13% remaining)
# Processed datadata_2017MagDown_157.root: 352 events before, 229 after (65.06% remaining)
# Processed datadata_2017MagDown_158.root: 401 events before, 234 after (58.35% remaining)
# Processed datadata_2017MagDown_159.root: 361 events before, 220 after (60.94% remaining)
# Processed datadata_2017MagDown_16.root: 338 events before, 191 after (56.51% remaining)
# Processed datadata_2017MagDown_160.root: 289 events before, 173 after (59.86% remaining)
# Processed datadata_2017MagDown_161.root: 331 events before, 191 after (57.70% remaining)
# Processed datadata_2017MagDown_162.root: 390 events before, 219 after (56.15% remaining)
# Processed datadata_2017MagDown_163.root: 369 events before, 220 after (59.62% remaining)
# Processed datadata_2017MagDown_164.root: 401 events before, 255 after (63.59% remaining)
# Processed datadata_2017MagDown_165.root: 399 events before, 252 after (63.16% remaining)
# Processed datadata_2017MagDown_166.root: 354 events before, 220 after (62.15% remaining)
# Processed datadata_2017MagDown_167.root: 411 events before, 255 after (62.04% remaining)
# Processed datadata_2017MagDown_168.root: 387 events before, 213 after (55.04% remaining)
# Processed datadata_2017MagDown_169.root: 350 events before, 207 after (59.14% remaining)
# Processed datadata_2017MagDown_17.root: 395 events before, 227 after (57.47% remaining)
# Processed datadata_2017MagDown_170.root: 350 events before, 205 after (58.57% remaining)
# Processed datadata_2017MagDown_171.root: 390 events before, 239 after (61.28% remaining)
# Processed datadata_2017MagDown_172.root: 350 events before, 216 after (61.71% remaining)
# Processed datadata_2017MagDown_173.root: 415 events before, 249 after (60.00% remaining)
# Processed datadata_2017MagDown_174.root: 369 events before, 211 after (57.18% remaining)
# Processed datadata_2017MagDown_175.root: 311 events before, 192 after (61.74% remaining)
# Processed datadata_2017MagDown_176.root: 363 events before, 236 after (65.01% remaining)
# Processed datadata_2017MagDown_177.root: 399 events before, 256 after (64.16% remaining)
# Processed datadata_2017MagDown_178.root: 327 events before, 205 after (62.69% remaining)
# Processed datadata_2017MagDown_179.root: 385 events before, 223 after (57.92% remaining)
# Processed datadata_2017MagDown_18.root: 382 events before, 231 after (60.47% remaining)
# Processed datadata_2017MagDown_180.root: 364 events before, 203 after (55.77% remaining)
# Processed datadata_2017MagDown_181.root: 396 events before, 215 after (54.29% remaining)
# Processed datadata_2017MagDown_182.root: 384 events before, 231 after (60.16% remaining)
# ...
# Processed datadata_2017MagDown_838.root: 354 events before, 205 after (57.91% remaining)
# Processed datadata_2017MagDown_839.root: 334 events before, 198 after (59.28% remaining)
# Processed datadata_2017MagDown_84.root: 328 events before, 189 after (57.62% remaining)
# Processed datadata_2017MagDown_840.root: 305 events before, 174 after (57.05% remaining)
# Processed datadata_2017MagDown_841.root: 312 events before, 174 after (55.77% remaining)
# Processed datadata_2017MagDown_842.root: 278 events before, 169 after (60.79% remaining)
# Processed datadata_2017MagDown_843.root: 354 events before, 210 after (59.32% remaining)
# Processed datadata_2017MagDown_844.root: 246 events before, 146 after (59.35% remaining)
# Processed datadata_2017MagDown_845.root: 383 events before, 230 after (60.05% remaining)
# Processed datadata_2017MagDown_846.root: 391 events before, 231 after (59.08% remaining)
# Processed datadata_2017MagDown_847.root: 417 events before, 262 after (62.83% remaining)
# Processed datadata_2017MagDown_848.root: 335 events before, 192 after (57.31% remaining)
# Processed datadata_2017MagDown_849.root: 390 events before, 257 after (65.90% remaining)
# Processed datadata_2017MagDown_85.root: 364 events before, 215 after (59.07% remaining)
# Processed datadata_2017MagDown_850.root: 323 events before, 186 after (57.59% remaining)
# Processed datadata_2017MagDown_851.root: 391 events before, 230 after (58.82% remaining)
# Processed datadata_2017MagDown_852.root: 424 events before, 260 after (61.32% remaining)
# Processed datadata_2017MagDown_853.root: 327 events before, 195 after (59.63% remaining)
# Processed datadata_2017MagDown_854.root: 357 events before, 212 after (59.38% remaining)
# Processed datadata_2017MagDown_855.root: 324 events before, 189 after (58.33% remaining)
# Processed datadata_2017MagDown_856.root: 282 events before, 160 after (56.74% remaining)
# Processed datadata_2017MagDown_857.root: 384 events before, 225 after (58.59% remaining)
# Processed datadata_2017MagDown_858.root: 367 events before, 222 after (60.49% remaining)
# Processed datadata_2017MagDown_859.root: 336 events before, 217 after (64.58% remaining)
# Processed datadata_2017MagDown_86.root: 409 events before, 232 after (56.72% remaining)
# Processed datadata_2017MagDown_860.root: 342 events before, 194 after (56.73% remaining)
# Processed datadata_2017MagDown_861.root: 382 events before, 235 after (61.52% remaining)
# Processed datadata_2017MagDown_862.root: 272 events before, 168 after (61.76% remaining)
# Processed datadata_2017MagDown_863.root: 320 events before, 199 after (62.19% remaining)
# Processed datadata_2017MagDown_864.root: 385 events before, 220 after (57.14% remaining)
# Processed datadata_2017MagDown_865.root: 283 events before, 170 after (60.07% remaining)
# Processed datadata_2017MagDown_866.root: 336 events before, 206 after (61.31% remaining)
# Processed datadata_2017MagDown_867.root: 280 events before, 175 after (62.50% remaining)
# Processed datadata_2017MagDown_868.root: 350 events before, 184 after (52.57% remaining)
# Processed datadata_2017MagDown_869.root: 357 events before, 209 after (58.54% remaining)
# Processed datadata_2017MagDown_87.root: 323 events before, 188 after (58.20% remaining)
# Processed datadata_2017MagDown_870.root: 341 events before, 189 after (55.43% remaining)
# Processed datadata_2017MagDown_871.root: 394 events before, 248 after (62.94% remaining)
# Processed datadata_2017MagDown_872.root: 375 events before, 227 after (60.53% remaining)
# Processed datadata_2017MagDown_873.root: 313 events before, 196 after (62.62% remaining)
# Processed datadata_2017MagDown_874.root: 329 events before, 215 after (65.35% remaining)
# Processed datadata_2017MagDown_875.root: 292 events before, 166 after (56.85% remaining)
# Processed datadata_2017MagDown_876.root: 393 events before, 238 after (60.56% remaining)
# Processed datadata_2017MagDown_877.root: 321 events before, 197 after (61.37% remaining)
# Processed datadata_2017MagDown_878.root: 277 events before, 164 after (59.21% remaining)
# Processed datadata_2017MagDown_879.root: 305 events before, 186 after (60.98% remaining)
# Processed datadata_2017MagDown_88.root: 305 events before, 181 after (59.34% remaining)
# Processed datadata_2017MagDown_880.root: 372 events before, 223 after (59.95% remaining)
# Processed datadata_2017MagDown_881.root: 368 events before, 224 after (60.87% remaining)
# Processed datadata_2017MagDown_882.root: 353 events before, 220 after (62.32% remaining)
# Processed datadata_2017MagDown_883.root: 374 events before, 229 after (61.23% remaining)
# Processed datadata_2017MagDown_884.root: 358 events before, 221 after (61.73% remaining)
# Processed datadata_2017MagDown_885.root: 381 events before, 234 after (61.42% remaining)
# Processed datadata_2017MagDown_886.root: 435 events before, 264 after (60.69% remaining)
# Processed datadata_2017MagDown_887.root: 452 events before, 262 after (57.96% remaining)
# Processed datadata_2017MagDown_888.root: 366 events before, 213 after (58.20% remaining)
# Processed datadata_2017MagDown_889.root: 373 events before, 220 after (58.98% remaining)
# Processed datadata_2017MagDown_89.root: 365 events before, 207 after (56.71% remaining)
# Processed datadata_2017MagDown_890.root: 315 events before, 191 after (60.63% remaining)
# Processed datadata_2017MagDown_891.root: 309 events before, 178 after (57.61% remaining)
# Processed datadata_2017MagDown_892.root: 434 events before, 252 after (58.06% remaining)
# Processed datadata_2017MagDown_893.root: 267 events before, 159 after (59.55% remaining)
# Processed datadata_2017MagDown_894.root: 338 events before, 191 after (56.51% remaining)
# Processed datadata_2017MagDown_895.root: 351 events before, 207 after (58.97% remaining)
# Processed datadata_2017MagDown_896.root: 337 events before, 205 after (60.83% remaining)
# Processed datadata_2017MagDown_897.root: 399 events before, 219 after (54.89% remaining)
# Processed datadata_2017MagDown_898.root: 361 events before, 231 after (63.99% remaining)
# Processed datadata_2017MagDown_899.root: 383 events before, 225 after (58.75% remaining)
# Processed datadata_2017MagDown_9.root: 354 events before, 224 after (63.28% remaining)
# Processed datadata_2017MagDown_90.root: 352 events before, 207 after (58.81% remaining)
# Processed datadata_2017MagDown_900.root: 368 events before, 245 after (66.58% remaining)
# Processed datadata_2017MagDown_901.root: 357 events before, 209 after (58.54% remaining)
# Processed datadata_2017MagDown_902.root: 388 events before, 228 after (58.76% remaining)
# Processed datadata_2017MagDown_903.root: 345 events before, 207 after (60.00% remaining)
# Processed datadata_2017MagDown_904.root: 375 events before, 223 after (59.47% remaining)
# Processed datadata_2017MagDown_905.root: 389 events before, 236 after (60.67% remaining)
# Processed datadata_2017MagDown_906.root: 342 events before, 210 after (61.40% remaining)
# Processed datadata_2017MagDown_907.root: 351 events before, 197 after (56.13% remaining)
# Processed datadata_2017MagDown_908.root: 323 events before, 193 after (59.75% remaining)
# Processed datadata_2017MagDown_909.root: 338 events before, 199 after (58.88% remaining)
# Processed datadata_2017MagDown_91.root: 325 events before, 191 after (58.77% remaining)
# Processed datadata_2017MagDown_910.root: 387 events before, 216 after (55.81% remaining)
# Processed datadata_2017MagDown_911.root: 382 events before, 235 after (61.52% remaining)
# Processed datadata_2017MagDown_912.root: 325 events before, 189 after (58.15% remaining)
# Processed datadata_2017MagDown_913.root: 408 events before, 282 after (69.12% remaining)
# Processed datadata_2017MagDown_914.root: 366 events before, 198 after (54.10% remaining)
# Processed datadata_2017MagDown_915.root: 299 events before, 187 after (62.54% remaining)
# Processed datadata_2017MagDown_916.root: 314 events before, 201 after (64.01% remaining)
# Processed datadata_2017MagDown_917.root: 330 events before, 193 after (58.48% remaining)
# Processed datadata_2017MagDown_918.root: 339 events before, 181 after (53.39% remaining)
# Processed datadata_2017MagDown_919.root: 364 events before, 207 after (56.87% remaining)
# Processed datadata_2017MagDown_92.root: 325 events before, 219 after (67.38% remaining)
# Processed datadata_2017MagDown_920.root: 419 events before, 254 after (60.62% remaining)
# Processed datadata_2017MagDown_921.root: 334 events before, 200 after (59.88% remaining)
# Processed datadata_2017MagDown_922.root: 299 events before, 166 after (55.52% remaining)
# Processed datadata_2017MagDown_923.root: 441 events before, 249 after (56.46% remaining)
# Processed datadata_2017MagDown_924.root: 349 events before, 210 after (60.17% remaining)
# Processed datadata_2017MagDown_925.root: 285 events before, 171 after (60.00% remaining)
# Processed datadata_2017MagDown_926.root: 351 events before, 228 after (64.96% remaining)
# Processed datadata_2017MagDown_927.root: 401 events before, 242 after (60.35% remaining)
# Processed datadata_2017MagDown_928.root: 296 events before, 200 after (67.57% remaining)
# Processed datadata_2017MagDown_929.root: 352 events before, 218 after (61.93% remaining)
# Processed datadata_2017MagDown_93.root: 353 events before, 219 after (62.04% remaining)
# Processed datadata_2017MagDown_930.root: 345 events before, 169 after (48.99% remaining)
# Processed datadata_2017MagDown_931.root: 279 events before, 173 after (62.01% remaining)
# Processed datadata_2017MagDown_932.root: 296 events before, 189 after (63.85% remaining)
# Processed datadata_2017MagDown_933.root: 385 events before, 224 after (58.18% remaining)
# Processed datadata_2017MagDown_934.root: 190 events before, 113 after (59.47% remaining)
# Processed datadata_2017MagDown_935.root: 401 events before, 229 after (57.11% remaining)
# Processed datadata_2017MagDown_936.root: 372 events before, 235 after (63.17% remaining)
# Processed datadata_2017MagDown_937.root: 334 events before, 191 after (57.19% remaining)
# Processed datadata_2017MagDown_938.root: 335 events before, 195 after (58.21% remaining)
# Processed datadata_2017MagDown_939.root: 378 events before, 212 after (56.08% remaining)
# Processed datadata_2017MagDown_94.root: 301 events before, 178 after (59.14% remaining)
# Processed datadata_2017MagDown_940.root: 370 events before, 217 after (58.65% remaining)
# Processed datadata_2017MagDown_941.root: 334 events before, 203 after (60.78% remaining)
# Processed datadata_2017MagDown_942.root: 379 events before, 227 after (59.89% remaining)
# Processed datadata_2017MagDown_943.root: 360 events before, 206 after (57.22% remaining)
# Processed datadata_2017MagDown_944.root: 347 events before, 193 after (55.62% remaining)
# Processed datadata_2017MagDown_945.root: 385 events before, 237 after (61.56% remaining)
# Processed datadata_2017MagDown_946.root: 293 events before, 168 after (57.34% remaining)
# Processed datadata_2017MagDown_947.root: 392 events before, 223 after (56.89% remaining)
# Processed datadata_2017MagDown_948.root: 308 events before, 188 after (61.04% remaining)
# Processed datadata_2017MagDown_949.root: 331 events before, 202 after (61.03% remaining)
# Processed datadata_2017MagDown_95.root: 368 events before, 216 after (58.70% remaining)
# Processed datadata_2017MagDown_950.root: 352 events before, 207 after (58.81% remaining)
# Processed datadata_2017MagDown_951.root: 413 events before, 252 after (61.02% remaining)
# Processed datadata_2017MagDown_952.root: 323 events before, 183 after (56.66% remaining)
# Processed datadata_2017MagDown_953.root: 387 events before, 225 after (58.14% remaining)
# Processed datadata_2017MagDown_954.root: 357 events before, 227 after (63.59% remaining)
# Processed datadata_2017MagDown_955.root: 286 events before, 177 after (61.89% remaining)
# Processed datadata_2017MagDown_956.root: 330 events before, 193 after (58.48% remaining)
# Processed datadata_2017MagDown_957.root: 378 events before, 223 after (58.99% remaining)
# Processed datadata_2017MagDown_958.root: 372 events before, 222 after (59.68% remaining)
# Processed datadata_2017MagDown_959.root: 345 events before, 207 after (60.00% remaining)
# Processed datadata_2017MagDown_96.root: 220 events before, 130 after (59.09% remaining)
# Processed datadata_2017MagDown_960.root: 388 events before, 228 after (58.76% remaining)
# Processed datadata_2017MagDown_961.root: 354 events before, 221 after (62.43% remaining)
# Processed datadata_2017MagDown_962.root: 371 events before, 215 after (57.95% remaining)
# Processed datadata_2017MagDown_963.root: 280 events before, 182 after (65.00% remaining)
# Processed datadata_2017MagDown_964.root: 365 events before, 201 after (55.07% remaining)
# Processed datadata_2017MagDown_965.root: 355 events before, 210 after (59.15% remaining)
# Processed datadata_2017MagDown_966.root: 345 events before, 203 after (58.84% remaining)
# Processed datadata_2017MagDown_967.root: 330 events before, 203 after (61.52% remaining)
# Processed datadata_2017MagDown_968.root: 403 events before, 248 after (61.54% remaining)
# Processed datadata_2017MagDown_969.root: 385 events before, 220 after (57.14% remaining)
# Processed datadata_2017MagDown_97.root: 340 events before, 194 after (57.06% remaining)
# Processed datadata_2017MagDown_970.root: 374 events before, 232 after (62.03% remaining)
# Processed datadata_2017MagDown_971.root: 378 events before, 223 after (58.99% remaining)
# Processed datadata_2017MagDown_972.root: 329 events before, 211 after (64.13% remaining)
# Processed datadata_2017MagDown_973.root: 447 events before, 277 after (61.97% remaining)
# Processed datadata_2017MagDown_974.root: 341 events before, 212 after (62.17% remaining)
# Processed datadata_2017MagDown_975.root: 357 events before, 213 after (59.66% remaining)
# Processed datadata_2017MagDown_976.root: 383 events before, 245 after (63.97% remaining)
# Processed datadata_2017MagDown_977.root: 343 events before, 192 after (55.98% remaining)
# Processed datadata_2017MagDown_978.root: 410 events before, 244 after (59.51% remaining)
# Processed datadata_2017MagDown_979.root: 351 events before, 215 after (61.25% remaining)
# Processed datadata_2017MagDown_98.root: 342 events before, 194 after (56.73% remaining)
# Processed datadata_2017MagDown_980.root: 347 events before, 220 after (63.40% remaining)
# Processed datadata_2017MagDown_981.root: 368 events before, 215 after (58.42% remaining)
# Processed datadata_2017MagDown_982.root: 393 events before, 242 after (61.58% remaining)
# Processed datadata_2017MagDown_983.root: 388 events before, 232 after (59.79% remaining)
# Processed datadata_2017MagDown_984.root: 365 events before, 210 after (57.53% remaining)
# Processed datadata_2017MagDown_985.root: 387 events before, 215 after (55.56% remaining)
# Processed datadata_2017MagDown_986.root: 382 events before, 239 after (62.57% remaining)
# Processed datadata_2017MagDown_987.root: 307 events before, 184 after (59.93% remaining)
# Processed datadata_2017MagDown_988.root: 349 events before, 209 after (59.89% remaining)
# Processed datadata_2017MagDown_989.root: 296 events before, 165 after (55.74% remaining)
# Processed datadata_2017MagDown_99.root: 355 events before, 208 after (58.59% remaining)
# Processed datadata_2017MagDown_990.root: 268 events before, 149 after (55.60% remaining)
# Processed datadata_2017MagDown_991.root: 360 events before, 199 after (55.28% remaining)
# Processed datadata_2017MagDown_992.root: 342 events before, 198 after (57.89% remaining)
# Processed datadata_2017MagDown_993.root: 333 events before, 204 after (61.26% remaining)
# Processed datadata_2017MagDown_994.root: 363 events before, 226 after (62.26% remaining)
# Processed datadata_2017MagDown_995.root: 326 events before, 189 after (57.98% remaining)
# Processed datadata_2017MagDown_996.root: 350 events before, 188 after (53.71% remaining)
# Processed datadata_2017MagDown_997.root: 331 events before, 190 after (57.40% remaining)
# Processed datadata_2017MagDown_998.root: 319 events before, 192 after (60.19% remaining)
# Processed datadata_2017MagDown_999.root: 401 events before, 231 after (57.61% remaining)

# %% [markdown]
# ## Run over possible pre-defined configration

# %%
# Possible configurations
decay_tree_lines = ['B2L0barPKpKm_LL', 'B2L0barPKpKm_DD']
years = ['2016', '2017']
magnet_polarizations = ['MagDown', 'MagUp']

# Set to a specific number for testing, or None for processing all files
num_files_for_testing = None  # or set to 16 for testing

# Iterate through all configurations and call main
for year in years:
    for magnet in magnet_polarizations:
        for decay_tree_line in decay_tree_lines:
            ll_or_dd = 'LL' if '_LL' in decay_tree_line else 'DD'
            decay_tree = f"{decay_tree_line}/DecayTree"

            # Call the main function with the current configuration
            # If num_files_for_testing is None, all files will be processed
            print(f"Processing: Year: {year}, Magnet: {magnet}, Decay Tree: {decay_tree}, Limit: {'All files' if num_files_for_testing is None else f'{num_files_for_testing} files'}")
            main(year, magnet, decay_tree, ll_or_dd, num_files=num_files_for_testing)
# Out:
# Processing: Year: 2016, Magnet: MagDown, Decay Tree: B2L0barPKpKm_LL/DecayTree, Limit: All files
# Output files will be saved in: /eos/lhcb/user/m/melashri/data/red_RD/B2L0barPKpKm/2016/MagDown/LL
# Processing files:  17%|█▋        | 277/1625 [02:04<10:19,  2.17it/s]

# %% [markdown]
# # Merging

# %%
def merge_root_files(base_directory, decay_trees, year=None, magnet=None, ll_or_dd=None):
    years = [year] if year else ['2016', '2017']
    magnets = [magnet] if magnet else ['MagDown', 'MagUp']
    ll_or_dds = [ll_or_dd] if ll_or_dd else ['LL', 'DD']

    for decay_tree_base in decay_trees:
        for year in years:
            for magnet in magnets:
                for ll_or_dd in ll_or_dds:
                    input_folder = os.path.join(base_directory, decay_tree_base, year, magnet, ll_or_dd)
                    if os.path.isdir(input_folder):
                        output_file = os.path.join(input_folder, f"merged_{decay_tree_base}_{year}_{magnet}_{ll_or_dd}.root")

                        # Check if merged file exists and is not corrupt
                        if os.path.exists(output_file) and not is_file_corrupt(output_file):
                            print(f"Merged file already exists and is not corrupt: {output_file}")
                            continue

                        files_to_merge = ' '.join([os.path.join(input_folder, f) for f in os.listdir(input_folder) if f.endswith('.root')])

                        # Constructing the hadd command
                        hadd_command = f"hadd -f {output_file} {files_to_merge}"

                        # Executing the command
                        try:
                            subprocess.run(hadd_command, shell=True, check=True)
                            print(f"Merged files in {input_folder}")
                        except subprocess.CalledProcessError as e:
                            print(f"Error merging files in {input_folder}: {e}")

# %%
base_directory = "/eos/lhcb/user/m/melashri/data/red_RD"
decay_trees = ['B2L0barPKpKm', 'B2L0barPKpKp']  # Specify the decay trees

merge_root_files(base_directory, decay_trees)

# %%
# # Example usage for a specific configuration
# base_directory = "/eos/lhcb/user/m/melashri/data/reduced"
# decay_trees = ['B2L0barPKpKm', 'B2L0barPKpKp']  # Specify the decay trees

# # Specific configuration
# specific_year = "2016"
# specific_magnet = "MagDown"
# specific_ll_or_dd = "LL"

# merge_root_files(base_directory, decay_trees, year=specific_year, magnet=specific_magnet, ll_or_dd=specific_ll_or_dd)
