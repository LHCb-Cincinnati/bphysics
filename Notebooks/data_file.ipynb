# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import vector  ## added by mds
import awkward as ak
import iminuit
from iminuit import Minuit
from fit_classes import *
from utils import *
import os

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
def load_data(decay_type=None, base_path=None, help=False, list_decay_types=False):
    if help:
        print("Usage: load_data(decay_type=None, base_path=None, help=False, list_decay_types=False)")
        print("decay_type: The specific decay type to load, or None to load all decay types.")
        print("base_path: The base path where the data files are located.")
        print("help: Set to True to print this help message.")
        print("list_decay_types: Set to True to list available decay types in the specified location.")
        return

    if base_path is None:
        raise ValueError("Please provide a base path for the data files.")

    all_files = [os.path.join(base_path, file) for file in os.listdir(base_path) if file.endswith(".root")]
    

    if list_decay_types:
        decay_types_per_file = {}
        for filename in all_files:
            file = uproot.open(filename)
            decay_types = set()
            for branch in file.keys():
                if 'DecayTree;1' in branch:
                    decay_type = branch.replace('/DecayTree;1', '')
                    decay_types.add(decay_type)
            decay_types_per_file[filename] = decay_types

        # Check if all files have the same decay types
        all_values = decay_types_per_file.values()
        if all(value == list(all_values)[0] for value in all_values):
            print('All files have the same decay types.')
            print('Available decay types:')
            for decay in list(all_values)[0]:
                print(decay)
        else:
            print('Not all files have the same decay types.')
            for file, decay_types in decay_types_per_file.items():
                print(f'File {file} has the decay types:')
                for decay_type in decay_types:
                    print(decay_type)
        return

    data = []
    for file_path in all_files:
        with uproot.open(file_path) as root_file:
            for key in root_file.keys():
                tree_name = key.split(';')[0]
                if decay_type is None or tree_name == decay_type:
                    data.append(f"{file_path}:{tree_name}/DecayTree")

    return data

# %%
def load_mc_data(base_path, selected_mc_types=None, decay_tree=None, list_decay_types=False):
    all_files = [os.path.join(base_path, file) for file in os.listdir(base_path) if file.endswith(".root")]

    if list_decay_types:
        # Extract unique MC types from the file names
        mc_types = set([file.rsplit('_', 1)[0] for file in os.listdir(base_path) if file.endswith('.root')])

        # Display the list of unique MC types to the user
        print("Available MC types:")
        for idx, mc_type in enumerate(mc_types, 1):
            print(f"{idx}. {mc_type}")

        # List available decay types
        decay_types_per_file = {}
        for filename in all_files:
            file = uproot.open(filename)
            decay_types = set()
            for branch in file.keys():
                if 'DecayTree;1' in branch:
                    decay_type = branch.replace('/DecayTree;1', '')
                    decay_types.add(decay_type)
            decay_types_per_file[filename] = decay_types

        # Check if all files have the same decay types
        all_values = decay_types_per_file.values()
        if all(value == list(all_values)[0] for value in all_values):
            print('All files have the same decay types.')
            print('Available decay types:')
            for decay in list(all_values)[0]:
                print(decay)
        else:
            print('Not all files have the same decay types.')
            for file, decay_types in decay_types_per_file.items():
                print(f'File {file} has the decay types:')
                for decay_type in decay_types:
                    print(decay_type)
        return

    if selected_mc_types is not None:
        all_files = [os.path.join(base_path, f"{selected_mc_type}_{year}.root") for selected_mc_type in selected_mc_types for year in ['15MU', '16MU', '17MU', '18MU', '15MD', '16MD', '17MD', '18MD']]

    data = []
    for file_path in all_files:
        with uproot.open(file_path) as root_file:
            for key in root_file.keys():
                tree_name = key.split(';')[0]
                if decay_tree is None or decay_tree in tree_name:
                    data.append(f"{file_path}:{tree_name}/DecayTree")

    return data

# %%
# Get the list of files
rd_data_files = load_data(base_path='/share/lazy/Bu2LambdaPHH/NTuples/RD/', decay_type ='B2L0pbarKpKp')

selected_mc_types = ['MCB2L0barPKpKm']
mc_data = load_mc_data(base_path='/share/lazy/Bu2LambdaPHH/NTuples/MC', selected_mc_types=selected_mc_types, decay_tree='B2L0pbarKpKp')

# %%
print(f"rd_data_files: {rd_data_files}")
print(f"mc_data: {mc_data}")
# Out:
# rd_data_files: ['/share/lazy/Bu2LambdaPHH/NTuples/RD/L0phh_15MD.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/RD/L0phh_15MU.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/RD/L0phh_16MD.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/RD/L0phh_16MU.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/RD/L0phh_17MD.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/RD/L0phh_17MU.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/RD/L0phh_18MD.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/RD/L0phh_18MU.root:B2L0pbarKpKp/DecayTree']
# mc_data: ['/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_15MU.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_15MU.root:B2L0pbarKpKp/DecayTree/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_16MU.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_16MU.root:B2L0pbarKpKp/DecayTree/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_17MU.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_17MU.root:B2L0pbarKpKp/DecayTree/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_18MU.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_18MU.root:B2L0pbarKpKp/DecayTree/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_15MD.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_15MD.root:B2L0pbarKpKp/DecayTree/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_16MD.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_16MD.root:B2L0pbarKpKp/DecayTree/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_17MD.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_17MD.root:B2L0pbarKpKp/DecayTree/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_18MD.root:B2L0pbarKpKp/DecayTree', '/share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_18MD.root:B2L0pbarKpKp/DecayTree/DecayTree']

# %%
arrs_rd = uproot.concatenate(rd_data_files)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 arrs_rd = uproot.concatenate(rd_data_files)
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:361, in concatenate(files, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, decompression_executor, interpretation_executor, library, ak_add_doc, how, custom_classes, allow_missing, **options)
#     359 with hasbranches:
#     360     try:
# --> 361         arrays = hasbranches.arrays(
#     362             expressions=expressions,
#     363             cut=cut,
#     364             filter_name=filter_name,
#     365             filter_typename=filter_typename,
#     366             filter_branch=filter_branch,
#     367             aliases=aliases,
#     368             language=language,
#     369             decompression_executor=decompression_executor,
#     370             interpretation_executor=interpretation_executor,
#     371             array_cache=None,
#     372             library=library,
#     373             ak_add_doc=ak_add_doc,
#     374             how=how,
#     375         )
#     376         arrays = library.global_index(arrays, global_start)
#     377     except uproot.exceptions.KeyInFileError:
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:810, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     807         return None
#     809 aliases = _regularize_aliases(self, aliases)
# --> 810 arrays, expression_context, branchid_interpretation = _regularize_expressions(
#     811     self,
#     812     expressions,
#     813     cut,
#     814     filter_name,
#     815     filter_typename,
#     816     filter_branch,
#     817     keys,
#     818     aliases,
#     819     language,
#     820     get_from_cache,
#     821 )
#     823 ranges_or_baskets = []
#     824 checked = set()
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:2881, in _regularize_expressions(hasbranches, expressions, cut, filter_name, filter_typename, filter_branch, keys, aliases, language, get_from_cache)
#    2867     for branchname, branch in hasbranches.iteritems(
#    2868         filter_name=filter_name,
#    2869         filter_typename=filter_typename,
#    (...)
#    2872         full_paths=False,
#    2873     ):
#    2874         if not isinstance(
#    2875             branch.interpretation,
#    2876             (
#    (...)
#    2879             ),
#    2880         ):
# -> 2881             _regularize_expression(
#    2882                 hasbranches,
#    2883                 language.getter_of(branchname),
#    2884                 keys,
#    2885                 aliases,
#    2886                 language,
#    2887                 get_from_cache,
#    2888                 arrays,
#    2889                 expression_context,
#    2890                 branchid_interpretation,
#    2891                 (),
#    2892                 False,
#    2893                 branchname,
#    2894             )
#    2896 elif uproot._util.isstr(expressions):
#    2897     _regularize_expression(
#    2898         hasbranches,
#    2899         expressions,
#    (...)
#    2909         None,
#    2910     )
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:2779, in _regularize_expression(hasbranches, expression, keys, aliases, language, get_from_cache, arrays, expression_context, branchid_interpretation, symbol_path, is_cut, rename)
#    2763 def _regularize_expression(
#    2764     hasbranches,
#    2765     expression,
#    (...)
#    2775     rename,
#    2776 ):
#    2777     is_primary = symbol_path == ()
# -> 2779     branch = hasbranches.get(expression)
#    2780     if branch is not None:
#    2781         _regularize_branchname(
#    2782             hasbranches,
#    2783             expression,
#    (...)
#    2791             is_cut,
#    2792         )
#
# File ~/.conda/envs/bphysics/lib/python3.10/_collections_abc.py:824, in Mapping.get(self, key, default)
#     822 'D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.'
#     823 try:
# --> 824     return self[key]
#     825 except KeyError:
#     826     return default
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:1651, in HasBranches.__getitem__(self, where)
#    1647         return got
#    1648     else:
#    1649         raise uproot.KeyInFileError(
#    1650             original_where,
# -> 1651             keys=self.keys(recursive=recursive),
#    1652             file_path=self._file.file_path,
#    1653             object_path=self.object_path,
#    1654         )
#    1656 else:
#    1657     raise uproot.KeyInFileError(
#    1658         original_where,
#    1659         keys=self.keys(recursive=recursive),
#    1660         file_path=self._file.file_path,
#    1661         object_path=self.object_path,
#    1662     )
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:1169, in HasBranches.keys(self, filter_name, filter_typename, filter_branch, recursive, full_paths)
#    1141 def keys(
#    1142     self,
#    1143     *,
#    (...)
#    1148     full_paths=True,
#    1149 ):
#    1150     """
#    1151     Args:
#    1152         filter_name (None, glob string, regex string in ``"/pattern/i"`` syntax, function of str \u2192 bool, or iterable of the above): A
#    (...)
#    1167     Returns the names of the subbranches as a list of strings.
#    1168     """
# -> 1169     return list(
#    1170         self.iterkeys(
#    1171             filter_name=filter_name,
#    1172             filter_typename=filter_typename,
#    1173             filter_branch=filter_branch,
#    1174             recursive=recursive,
#    1175             full_paths=full_paths,
#    1176         )
#    1177     )
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:1322, in HasBranches.iterkeys(self, filter_name, filter_typename, filter_branch, recursive, full_paths)
#    1294 def iterkeys(
#    1295     self,
#    1296     *,
#    (...)
#    1301     full_paths=True,
#    1302 ):
#    1303     """
#    1304     Args:
#    1305         filter_name (None, glob string, regex string in ``"/pattern/i"`` syntax, function of str \u2192 bool, or iterable of the above): A
#    (...)
#    1320     Returns the names of the subbranches as an iterator over strings.
#    1321     """
# -> 1322     for k, _ in self.iteritems(
#    1323         filter_name=filter_name,
#    1324         filter_typename=filter_typename,
#    1325         filter_branch=filter_branch,
#    1326         recursive=recursive,
#    1327         full_paths=full_paths,
#    1328     ):
#    1329         yield k
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:1419, in HasBranches.iteritems(self, filter_name, filter_typename, filter_branch, recursive, full_paths)
#    1410 for branch in self.branches:
#    1411     if (
#    1412         (
#    1413             filter_name is no_filter
#    (...)
#    1417         and (filter_branch is no_filter or filter_branch(branch))
#    1418     ):
# -> 1419         yield branch.name, branch
#    1421     if recursive:
#    1422         for k1, v in branch.iteritems(
#    1423             recursive=recursive,
#    1424             filter_name=no_filter,
#    (...)
#    1427             full_paths=full_paths,
#    1428         ):
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:1869, in TBranch.name(self)
#    1860 @property
#    1861 def name(self):
#    1862     """
#    1863     Name of the ``TBranch``.
#    1864
#    (...)
#    1867     :ref:`uproot.behaviors.TBranch.TBranch.index`.
#    1868     """
# -> 1869     return self.member("fName")
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/model.py:550, in Model.member(self, name, all, none_if_missing)
#     548 if all:
#     549     for base in reversed(self._bases):
# --> 550         if base.has_member(name, all=True):
#     551             return base.member(name, all=True)
#     553 if none_if_missing:
#
# File ~/.conda/envs/bphysics/lib/python3.10/site-packages/uproot/model.py:518, in Model.has_member(self, name, all)
#     515     out.update(self._members)
#     516     return out
# --> 518 def has_member(self, name, all=True):
#     519     """
#     520     Returns True if calling :ref:`uproot.model.Model.member` with the same
#     521     arguments would return a value; False if the member is missing.
#     522     """
#     523     if name in self._members:
#
# KeyboardInterrupt:

# %%
load_mc_data(list_decay_types=True, base_path='/share/lazy/Bu2LambdaPHH/NTuples/MC/')
# Out:
# Available MC types:
# 1. MCBd2L0barPDm,KPiPi
# 2. MCBs2L0barPDsm,KKPi
# 3. MCBd2LcPiPiP,L0barPi
# 4. MCB2L0barPKpKm
# 5. MCBu2LcbarPPi,L0barPim
# 6. MCBd2L0barPDm,KKPi
# 7. MCBu2L0barPD0bar,KPi
# 8. MCB2L0PbarKpPip
# 9. MCBu2L0barLambda1520K,PK
# 10. MCB2L0PbarKpKp
# 11. MCBu2L0barPPhi,KK
# 12. MCB2PPbarPPbarPip
# 13. MCBu2chic1K
# 14. MCBu2etacK,PL0barK
# 15. MCBu2chic2K
# 16. MCBu2LcbarPPi,Sigma0barPiPi0
# 17. MCB2L0barPKmPip
# 18. MCBs2L0barPDssm,Dsgamma,KKPi
# 19. MCBu2L0barPetaP
# 20. MCBu2chic0K
# 21. MCBu2L0barPD0bar,KPiPi0
# 22. MCB2L0barPJpsi,PPbar
# 23. MCBu2LcbarPPi,Sigma0barPi
# 24. MCB2L0barPPipPip
# 25. MCBu2Psi2SK
# 26. MCB2L0barPPipPim
# 27. MCB2L0barPPbarP
# 28. MCB2L0barPKpPim
# 29. MCBd2LcbarL0K,PKPi
# 30. MCBu2JpsiK,PL0barK
# 31. MCBu2LcbarPPi,L0barPiPi0
# 32. MCBd2L0barPDsm,KKPi
# 33. MCBu2L0barPeta,PiPiX
# Not all files have the same decay types.
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPJpsi,PPbar_15MD.root has the decay types:
# B2L0barpKpKm
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPJpsi,PPbar_15MU.root has the decay types:
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPJpsi,PPbar_16MD.root has the decay types:
# B2L0barppippim
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPJpsi,PPbar_16MU.root has the decay types:
# B2L0barppippim
# B2L0pbarKppip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPJpsi,PPbar_17MD.root has the decay types:
# B2L0barppippim
# B2L0pbarKppip
# B2L0barpKmpip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPJpsi,PPbar_17MU.root has the decay types:
# B2L0barppippim
# B2L0barpKppim
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPJpsi,PPbar_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPJpsi,PPbar_18MU.root has the decay types:
# B2L0barppippim
# B2L0pbarpippip
# B2L0barpKppim
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKmPip_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKmPip_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKmPip_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKmPip_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKmPip_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKmPip_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKmPip_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKmPip_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpKm_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpPim_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpPim_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpPim_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpPim_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpPim_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpPim_17MU.root has the decay types:
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpPim_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPKpPim_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPbarP_15MD.root has the decay types:
# MC_B2L0barppbarp/MCDecayTree;1
# B2L0barpKpKm
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPbarP_15MU.root has the decay types:
# B2L0barppippim
# MC_B2L0barppbarp/MCDecayTree;1
# B2L0pbarpippip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPbarP_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPbarP_16MU.root has the decay types:
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPbarP_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPbarP_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPbarP_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPbarP_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPim_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPim_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPim_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPim_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPim_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPim_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPim_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPim_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# MC_B2L0barppippim/MCDecayTree;1
# B2L0barppbarp
# MC_B2L0barppbarp/MCDecayTree;1
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPip_15MD.root has the decay types:
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPip_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPip_16MD.root has the decay types:
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPip_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPip_17MD.root has the decay types:
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPip_17MU.root has the decay types:
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPip_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0barPPipPip_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpKp_15MD.root has the decay types:
# B2L0pbarKpKp
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpKp_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpKp_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpKp_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpKp_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpKp_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpKp_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpKp_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpPip_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpPip_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpPip_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpPip_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpPip_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpPip_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpPip_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2L0PbarKpPip_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2PPbarPPbarPip_15MD.root has the decay types:
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2PPbarPPbarPip_15MU.root has the decay types:
# B2L0barppippim
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2PPbarPPbarPip_16MD.root has the decay types:
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2PPbarPPbarPip_16MU.root has the decay types:
# B2L0barppippim
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2PPbarPPbarPip_17MD.root has the decay types:
# B2L0pbarKppip
# B2L0barppippim
# B2L0barpKppim
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2PPbarPPbarPip_17MU.root has the decay types:
# B2L0barppippim
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2PPbarPPbarPip_18MD.root has the decay types:
# B2L0pbarpippip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCB2PPbarPPbarPip_18MU.root has the decay types:
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KKPi_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KKPi_15MU.root has the decay types:
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KKPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KKPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KKPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KKPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KKPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KKPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KPiPi_15MD.root has the decay types:
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KPiPi_15MU.root has the decay types:
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KPiPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KPiPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KPiPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KPiPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KPiPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDm,KPiPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDsm,KKPi_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDsm,KKPi_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDsm,KKPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDsm,KKPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDsm,KKPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDsm,KKPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDsm,KKPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2L0barPDsm,KKPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcbarL0K,PKPi_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcbarL0K,PKPi_15MU.root has the decay types:
# B2L0pbarKpKp
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcbarL0K,PKPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcbarL0K,PKPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcbarL0K,PKPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcbarL0K,PKPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcbarL0K,PKPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcbarL0K,PKPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcPiPiP,L0barPi_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcPiPiP,L0barPi_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcPiPiP,L0barPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcPiPiP,L0barPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcPiPiP,L0barPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcPiPiP,L0barPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcPiPiP,L0barPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBd2LcPiPiP,L0barPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDsm,KKPi_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDsm,KKPi_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDsm,KKPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDsm,KKPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDsm,KKPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDsm,KKPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDsm,KKPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDsm,KKPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDssm,Dsgamma,KKPi_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDssm,Dsgamma,KKPi_15MU.root has the decay types:
# B2L0pbarKppip
# B2L0barpKmpip
# B2L0barpKppim
# B2L0barpKpKm
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDssm,Dsgamma,KKPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDssm,Dsgamma,KKPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDssm,Dsgamma,KKPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDssm,Dsgamma,KKPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDssm,Dsgamma,KKPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBs2L0barPDssm,Dsgamma,KKPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic0K_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic0K_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic0K_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic0K_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic0K_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic0K_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic0K_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic0K_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic1K_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic1K_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic1K_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic1K_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic1K_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic1K_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic1K_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic1K_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic2K_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic2K_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic2K_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic2K_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic2K_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic2K_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic2K_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2chic2K_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2etacK,PL0barK_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2etacK,PL0barK_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2etacK,PL0barK_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2etacK,PL0barK_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2etacK,PL0barK_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2etacK,PL0barK_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2etacK,PL0barK_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2etacK,PL0barK_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2JpsiK,PL0barK_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2JpsiK,PL0barK_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2JpsiK,PL0barK_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2JpsiK,PL0barK_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2JpsiK,PL0barK_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2JpsiK,PL0barK_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2JpsiK,PL0barK_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2JpsiK,PL0barK_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barLambda1520K,PK_15MD.root has the decay types:
# B2L0barpKppim
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppbarp
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barLambda1520K,PK_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barLambda1520K,PK_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barLambda1520K,PK_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barLambda1520K,PK_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barLambda1520K,PK_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barLambda1520K,PK_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barLambda1520K,PK_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPi_15MD.root has the decay types:
# B2L0barppippim
# B2L0pbarpippip
# B2L0barpKppim
# B2L0barpKpKm
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPi_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPiPi0_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPiPi0_15MU.root has the decay types:
# B2L0barpKppim
# B2L0pbarpippip
# B2L0barpKpKm
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPiPi0_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPiPi0_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPiPi0_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPiPi0_17MU.root has the decay types:
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPiPi0_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPD0bar,KPiPi0_18MU.root has the decay types:
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPetaP_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPetaP_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0pbarpippip
# B2L0barpKppim
# B2L0barppippim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPetaP_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPetaP_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPetaP_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPetaP_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPetaP_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPetaP_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPeta,PiPiX_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPeta,PiPiX_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPeta,PiPiX_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPeta,PiPiX_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPeta,PiPiX_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPeta,PiPiX_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPeta,PiPiX_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPeta,PiPiX_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPPhi,KK_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPPhi,KK_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPPhi,KK_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPPhi,KK_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPPhi,KK_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPPhi,KK_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPPhi,KK_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2L0barPPhi,KK_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPim_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPim_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPim_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPim_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPim_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPim_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPim_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPim_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPiPi0_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPiPi0_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPiPi0_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPiPi0_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPiPi0_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPiPi0_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPiPi0_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,L0barPiPi0_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPi_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPi_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0pbarpippip
# B2L0barpKppim
# B2L0barppippim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPi_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPi_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPi_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPi_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPi_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPi_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPiPi0_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPiPi0_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0pbarpippip
# B2L0barpKppim
# B2L0barppippim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPiPi0_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPiPi0_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPiPi0_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPiPi0_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPiPi0_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2LcbarPPi,Sigma0barPiPi0_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2Psi2SK_15MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2Psi2SK_15MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2Psi2SK_16MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2Psi2SK_16MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2Psi2SK_17MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2Psi2SK_17MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2Psi2SK_18MD.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0pbarpippip
# B2L0barppbarp
# B2L0barpKppim
# File /share/lazy/Bu2LambdaPHH/NTuples/MC/MCBu2Psi2SK_18MU.root has the decay types:
# B2L0barpKmpip
# B2L0barpKpKm
# B2L0barppippim
# B2L0pbarKpKp
# B2L0pbarKppip
# B2L0barppbarp
# B2L0barpKppim
